# %% [markdown]
# ## Preprocessing

# %% [markdown]
# The first thing we need to do is to preprocess the data. We will start by loading the data and taking a look at its head, tail and also its general information.

# %%
import pandas as pd 

df = pd.read_csv("houses_with_new_features.csv")

df.head()
# Out:
#    zipcode              streetAddress     homeStatus           homeType  \
# 0    90049  11645 Montana Ave APT 229  RECENTLY_SOLD              CONDO
# 1    90046         2316 Laurelmont Pl  RECENTLY_SOLD  HOME_TYPE_UNKNOWN
# 2    91406        6452 Woodley Ave #3  RECENTLY_SOLD          APARTMENT
# 3    91406    6452 Woodley Ave UNIT 2  RECENTLY_SOLD  HOME_TYPE_UNKNOWN
# 4    90059          855 E 120th St #3  RECENTLY_SOLD          APARTMENT
#
#     latitude   longitude  yearBuilt  lotAreaValue lotAreaUnits  \
# 0  34.056390 -118.465990     1973.0        1.1479        Acres
# 1  34.113050 -118.371925        NaN     1970.0000  Square Feet
# 2  34.188200 -118.483284     2006.0           NaN         sqft
# 3  34.188200 -118.483284        NaN           NaN         sqft
# 4  33.924007 -118.259570        NaN           NaN         sqft
#
#    livingAreaValue  ... currency  parkingCapacity  hasCooling  hasHeating  \
# 0            855.0  ...      USD                4        True        True
# 1              NaN  ...      USD                0       False       False
# 2           1800.0  ...      USD                2        True        True
# 3              NaN  ...      USD                0       False       False
# 4            912.0  ...      USD                0       False       False
#
#    hasFireplace  hasPrivatePool hasSpa hasView  \
# 0          True             NaN   True    True
# 1           NaN             NaN  False   False
# 2           NaN             NaN  False   False
# 3           NaN             NaN  False   False
# 4           NaN             NaN  False   False
#
#                                     securityFeatures Unnamed: 38
# 0  ['Automatic Gate', 'Fire and Smoke Detection S...         NaN
# 1                                                NaN         NaN
# 2                                                NaN         NaN
# 3                                                NaN         NaN
# 4                                                NaN         NaN
#
# [5 rows x 39 columns]

# %%
df.tail()
# Out:
#       zipcode     streetAddress     homeStatus       homeType   latitude  \
# 5601    90077      825 Nimes Pl  RECENTLY_SOLD  SINGLE_FAMILY  34.088142
# 5602    90272     839 Toyopa Dr  RECENTLY_SOLD  SINGLE_FAMILY  34.043210
# 5603    90024  467 Comstock Ave  RECENTLY_SOLD  SINGLE_FAMILY  34.074005
# 5604    90049   255 Ashdale Ave  RECENTLY_SOLD  SINGLE_FAMILY  34.077225
# 5605    90049    543 Moreno Ave  RECENTLY_SOLD  SINGLE_FAMILY  34.046860
#
#       longitude  yearBuilt  lotAreaValue lotAreaUnits  livingAreaValue  ...  \
# 5601 -118.44139     1952.0      0.699885        Acres           6000.0  ...
# 5602 -118.52257     2023.0   8624.880000  Square Feet           8438.0  ...
# 5603 -118.43295     2021.0      0.505200        Acres           9500.0  ...
# 5604 -118.46199     2023.0      0.416300        Acres           8726.0  ...
# 5605 -118.48794     1938.0      0.365496        Acres           4489.0  ...
#
#      currency  parkingCapacity  hasCooling  hasHeating  hasFireplace  \
# 5601      USD                1        True        True          True
# 5602      USD                6        True        True          True
# 5603      USD                5        True        True          True
# 5604      USD                2        True        True          True
# 5605      USD                3        True        True          True
#
#       hasPrivatePool hasSpa hasView           securityFeatures Unnamed: 38
# 5601             NaN  False    True                        NaN         NaN
# 5602             NaN  False    True                        NaN         NaN
# 5603             NaN  False    True  ['Gated', 'Alarm System']         NaN
# 5604            True  False    True           ['Alarm System']         NaN
# 5605             NaN   True   False                        NaN         NaN
#
# [5 rows x 39 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5606 entries, 0 to 5605
# Data columns (total 39 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   zipcode                5606 non-null   int64
#  1   streetAddress          5606 non-null   object
#  2   homeStatus             5606 non-null   object
#  3   homeType               5606 non-null   object
#  4   latitude               5602 non-null   float64
#  5   longitude              5602 non-null   float64
#  6   yearBuilt              5391 non-null   float64
#  7   lotAreaValue           5438 non-null   float64
#  8   lotAreaUnits           5606 non-null   object
#  9   livingAreaValue        5439 non-null   float64
#  10  livingAreaUnitsShort   5438 non-null   object
#  11  garageParkingCapacity  3393 non-null   float64
#  12  bedrooms               5429 non-null   float64
#  13  bathrooms              5437 non-null   float64
#  14  bathroomsFull          4640 non-null   float64
#  15  stories                4347 non-null   float64
#  16  flooring               4066 non-null   object
#  17  foundationDetails      5546 non-null   object
#  18  heating                4995 non-null   object
#  19  cooling                5361 non-null   object
#  20  fireplaceFeatures      4408 non-null   object
#  21  sewer                  3189 non-null   object
#  22  roofType               1264 non-null   object
#  23  taxAssessedValue       5040 non-null   float64
#  24  zestimate              5185 non-null   float64
#  25  rentZestimate          5563 non-null   float64
#  26  sold-history           5606 non-null   object
#  27  pricePerSquareFoot     5433 non-null   float64
#  28  price                  5606 non-null   int64
#  29  currency               5606 non-null   object
#  30  parkingCapacity        5606 non-null   int64
#  31  hasCooling             5399 non-null   object
#  32  hasHeating             4995 non-null   object
#  33  hasFireplace           4565 non-null   object
#  34  hasPrivatePool         585 non-null    object
#  35  hasSpa                 5606 non-null   bool
#  36  hasView                5606 non-null   bool
#  37  securityFeatures       1987 non-null   object
#  38  Unnamed: 38            0 non-null      float64
# dtypes: bool(2), float64(15), int64(3), object(19)
# memory usage: 1.6+ MB

# %% [markdown]
# First we look at zipcodes and their values seem ok.

# %% [markdown]
# ### Removing duplicates

# %% [markdown]
# We will remove duplicates from the data. As you can see below, there were no duplicates in the data.

# %%
print("size before duplication removal: ", df.shape)

df.drop_duplicates(inplace=True)

print("size after duplication removal: ", df.shape)
# Out:
# size before duplication removal:  (5606, 39)
# size after duplication removal:  (5606, 39)

# %%
df['zipcode'].describe()
# Out:
# count     5606.000000
# mean     90641.699072
# std       1127.441034
# min      21550.000000
# 25%      90041.000000
# 50%      90272.000000
# 75%      91342.000000
# max      91607.000000
# Name: zipcode, dtype: float64

# %% [markdown]
# ### Checking the number of missing values
#
# Here we only check the number of missing values for each column and later we will deal with them.

# %%
df.isnull().sum()
# Out:
# zipcode                     0
# streetAddress               0
# homeStatus                  0
# homeType                    0
# latitude                    4
# longitude                   4
# yearBuilt                 215
# lotAreaValue              168
# lotAreaUnits                0
# livingAreaValue           167
# livingAreaUnitsShort      168
# garageParkingCapacity    2213
# bedrooms                  177
# bathrooms                 169
# bathroomsFull             966
# stories                  1259
# flooring                 1540
# foundationDetails          60
# heating                   611
# cooling                   245
# fireplaceFeatures        1198
# sewer                    2417
# roofType                 4342
# taxAssessedValue          566
# zestimate                 421
# rentZestimate              43
# sold-history                0
# pricePerSquareFoot        173
# price                       0
# currency                    0
# parkingCapacity             0
# hasCooling                207
# hasHeating                611
# hasFireplace             1041
# hasPrivatePool           5021
# hasSpa                      0
# hasView                     0
# securityFeatures         3619
# Unnamed: 38              5606
# dtype: int64

# %% [markdown]
# ### Handling Home Status

# %% [markdown]
# We check the home status. We can see that although we only scraped sold houses, there are some houses that have different statuses. The reason is between the time we scraped the links of sold houses and the time we scraped the data of the houses, some houses were put on the market again. We will remove these houses from the data and save them in a separate file so maybe we can use them in the future.

# %%
df["homeStatus"].value_counts()
# Out:
# homeStatus
# RECENTLY_SOLD      5434
# FOR_SALE             81
# FOR_RENT             60
# PENDING              16
# PRE_FORECLOSURE      11
# FORECLOSED            2
# OTHER                 2
# Name: count, dtype: int64

# %%
df_not_sold = df[df['homeStatus'] != 'RECENTLY_SOLD']

df = df[df['homeStatus'] == 'RECENTLY_SOLD']

# %%
df_not_sold.head()
# Out:
#      zipcode                streetAddress homeStatus       homeType  \
# 111    90057                216 S Lake St   FOR_SALE  SINGLE_FAMILY
# 161    90020    360 S Kenmore Ave APT 310   FOR_SALE          CONDO
# 179    91342  14075 Foothill Blvd APT 13A   FOR_SALE          CONDO
# 192    91316    5400 Newcastle Ave APT 42   FOR_SALE          CONDO
# 279    91402          8801 Willis Ave #31   FOR_RENT      APARTMENT
#
#       latitude   longitude  yearBuilt  lotAreaValue lotAreaUnits  \
# 111  34.065617 -118.271940     1903.0     6098.4000  Square Feet
# 161  34.067370 -118.296265     1965.0        0.3486        Acres
# 179  34.315300 -118.439770     1977.0        0.4986        Acres
# 192  34.168633 -118.523580     1967.0        1.3996        Acres
# 279  34.230145 -118.455894        NaN           NaN         sqft
#
#      livingAreaValue  ... currency  parkingCapacity  hasCooling  hasHeating  \
# 111           3323.0  ...      USD                0         NaN         NaN
# 161            603.0  ...      USD                1        True        True
# 179            615.0  ...      USD                2        True        True
# 192            648.0  ...      USD                1        True        True
# 279            997.0  ...      USD                0        True         NaN
#
#      hasFireplace  hasPrivatePool hasSpa hasView  \
# 111           NaN             NaN  False   False
# 161         False             NaN  False    True
# 179         False             NaN  False    True
# 192         False             NaN   True    True
# 279           NaN             NaN  False   False
#
#                                       securityFeatures Unnamed: 38
# 111                                                NaN         NaN
# 161                                           ['None']         NaN
# 179  ['Gated', 'Secured Community', 'Security Light...         NaN
# 192                                                NaN         NaN
# 279                                                NaN         NaN
#
# [5 rows x 39 columns]

# %%
df_not_sold.to_csv("not_sold.csv", index=False)

# %% [markdown]
# Now all of the houses have the same status so we can drop this column.

# %%
df.drop(columns=['homeStatus'], inplace=True)

# %% [markdown]
# ### Home Types

# %% [markdown]
# We check the unique values of the home types. We can see that we have 37 rows with `HOME_TYPE_UNKNOWN` and since it's a small number, we will remove them from the data.

# %%
df["homeType"].value_counts()
# Out:
# homeType
# SINGLE_FAMILY        3443
# CONDO                 971
# MULTI_FAMILY          473
# TOWNHOUSE             317
# LOT                   110
# MANUFACTURED           48
# HOME_TYPE_UNKNOWN      37
# APARTMENT              35
# Name: count, dtype: int64

# %%
df = df[df["homeType"] != "HOME_TYPE_UNKNOWN"]

# %% [markdown]
# ### Latitude and Longitude

# %% [markdown]
# We check the distribution of the latitude and longitude values. We see that all of them are in a small range(Because all of them belong to Los Angeles) and since we also have zipcode for grouping them by location, we can drop these columns.

# %%
df["latitude"].describe()
# Out:
# count    5393.000000
# mean       34.102236
# std         0.120297
# min        33.706684
# 25%        34.038242
# 50%        34.105583
# 75%        34.190070
# max        34.326786
# Name: latitude, dtype: float64

# %%
df["longitude"].describe()
# Out:
# count    5393.000000
# mean     -118.403168
# std         0.115175
# min      -118.667270
# 25%      -118.477260
# 50%      -118.404440
# 75%      -118.307080
# max      -118.159600
# Name: longitude, dtype: float64

# %%
df.drop(columns=['latitude', 'longitude'], inplace=True)

# %% [markdown]
# ### Year Built

# %% [markdown]
# We can see we have one of the houses has a year built of 0. We will remove this house from the data.

# %%
df["yearBuilt"].describe()
# Out:
# count    5255.000000
# mean     1960.963463
# std        40.234308
# min         0.000000
# 25%      1941.000000
# 50%      1957.000000
# 75%      1980.000000
# max      2024.000000
# Name: yearBuilt, dtype: float64

# %%
df[df["yearBuilt"] < 1900]
# Out:
#       zipcode           streetAddress       homeType  yearBuilt  lotAreaValue  \
# 64      91307        22710 Saticoy St  SINGLE_FAMILY        0.0     8460.0000
# 383     90012  257 S Spring St APT 4L          CONDO     1899.0        0.6616
# 1069    90011           223 E 24th St  SINGLE_FAMILY     1899.0     5249.0000
# 1092    90026          1309 Colton St  SINGLE_FAMILY     1885.0     5571.0000
# 1365    90026        1526 Rockwood St  SINGLE_FAMILY     1885.0     5969.0000
# 1694    90031         300 S Avenue 19   MULTI_FAMILY     1895.0     7500.0000
# 1964    90031        2621 Johnston St  SINGLE_FAMILY     1895.0        0.2702
# 3075    90006           1116 Irolo St  SINGLE_FAMILY     1896.0     5906.7360
# 3435    90033       2014 Michigan Ave   MULTI_FAMILY     1890.0     7413.9120
# 3607    90026       2128 Reservoir St  SINGLE_FAMILY     1895.0     7744.9680
# 4051    90007          1033 W 30th St  SINGLE_FAMILY     1890.0     6842.0000
#
#      lotAreaUnits  livingAreaValue livingAreaUnitsShort  \
# 64          Acres           1372.0                 sqft
# 383         Acres            650.0                 sqft
# 1069  Square Feet           1205.0                 sqft
# 1092  Square Feet            852.0                 sqft
# 1365  Square Feet            880.0                 sqft
# 1694  Square Feet           1952.0                 sqft
# 1964        Acres           1800.0                 sqft
# 3075  Square Feet           1718.0                 sqft
# 3435  Square Feet           2952.0                 sqft
# 3607  Square Feet           1770.0                 sqft
# 4051  Square Feet           1655.0                 sqft
#
#       garageParkingCapacity  bedrooms  ...  currency  parkingCapacity  \
# 64                      NaN       4.0  ...       USD                0
# 383                     1.0       0.0  ...       USD                1
# 1069                    0.0       2.0  ...       USD                0
# 1092                    NaN       2.0  ...       USD                0
# 1365                    0.0       1.0  ...       USD                1
# 1694                    0.0       2.0  ...       USD                3
# 1964                    NaN       3.0  ...       USD                0
# 3075                    NaN       3.0  ...       USD                6
# 3435                    NaN       7.0  ...       USD                0
# 3607                    NaN       4.0  ...       USD                3
# 4051                    1.0       3.0  ...       USD                1
#
#       hasCooling hasHeating hasFireplace hasPrivatePool hasSpa hasView  \
# 64           NaN        NaN          NaN            NaN  False   False
# 383         True       True        False            NaN  False    True
# 1069       False        NaN        False            NaN  False    True
# 1092       False       True          NaN            NaN  False   False
# 1365       False       True        False            NaN  False    True
# 1694         NaN        NaN          NaN            NaN  False   False
# 1964       False      False        False            NaN  False    True
# 3075        True       True        False            NaN  False    True
# 3435        True       True          NaN            NaN  False   False
# 3607        True       True        False            NaN  False    True
# 4051       False        NaN        False            NaN  False    True
#
#                                        securityFeatures Unnamed: 38
# 64                                                  NaN         NaN
# 383   ['Gated with Guard', 'Gated', 'Other', 'Card/C...         NaN
# 1069                                                NaN         NaN
# 1092                                                NaN         NaN
# 1365                    ['Carbon Monoxide Detector(s)']         NaN
# 1694                                                NaN         NaN
# 1964                                                NaN         NaN
# 3075                                                NaN         NaN
# 3435                                                NaN         NaN
# 3607  ['Carbon Monoxide Detector(s)', 'Security Ligh...         NaN
# 4051                                                NaN         NaN
#
# [11 rows x 36 columns]

# %%
df = df[df["yearBuilt"] > 0]

# %%
df["yearBuilt"] = df["yearBuilt"].astype(int)

# %% [markdown]
# ### lot area and living area

# %% [markdown]
# lot area and living area have different units so the first thing we do is to convert them to the square.

# %% [markdown]
# First we drop the rows with missing values in these columns:

# %%
df.dropna(subset=['lotAreaValue', 'livingAreaValue', 'livingAreaUnitsShort'], inplace=True)

# %%
df["lotAreaUnits"].unique()
# Out:
# array(['Acres', 'Square Feet'], dtype=object)

# %%
df["lotAreaUnits"] = df["lotAreaUnits"].replace("Square Feet", 'sqft')

# %%
conversion_factors = {
    'sqft': 0.092903,
    'Acres': 4046.86,
}

df['lotAreaValue'] = df.apply(
    lambda row: row['lotAreaValue'] * conversion_factors[row['lotAreaUnits']],
    axis=1
)

# %%
df["livingAreaUnitsShort"].unique()
# Out:
# array(['sqft'], dtype=object)

# %%
df['livingAreaValue'] = df.apply(
    lambda row: row['livingAreaValue'] * conversion_factors[row['livingAreaUnitsShort']],
    axis=1
)

# %% [markdown]
# Now in order to clean the data we replace the lot values that are less than a threshold or are less than living area with living area of the house.

# %%
df["lotAreaValue"].describe()
# Out:
# count    5.157000e+03
# mean     3.520450e+05
# std      2.292609e+07
# min      0.000000e+00
# 25%      5.530516e+02
# 50%      6.990951e+02
# 75%      1.551947e+03
# max      1.644773e+09
# Name: lotAreaValue, dtype: float64

# %%
df[(df["lotAreaValue"] < df["livingAreaValue"]) & (df["lotAreaValue"] > 0.1)]
# Out:
#       zipcode           streetAddress       homeType  yearBuilt  lotAreaValue  \
# 6       91303  7305 Milwood Ave APT 3          CONDO       1981     80.918513
# 85      91601   5706 Fair Ave APT 200          CONDO       1981     81.754640
# 1186    90037     1006 W Leighton Ave      TOWNHOUSE       2008    112.133921
# 1345    90011       4146 Woodlawn Ave   MULTI_FAMILY       1906    359.070095
# 1547    91405        14104 W Birch Ln  SINGLE_FAMILY       2016    101.171367
# ...       ...                     ...            ...        ...           ...
# 5556    90272       756 Via De La Paz  SINGLE_FAMILY       2016    696.868376
# 5570    91303        21121 Vanowen St  SINGLE_FAMILY       2021   2623.491266
# 5581    90004        4804 Oakwood Ave      APARTMENT       2022   1347.095271
# 5597    90021          1001 Towne Ave  SINGLE_FAMILY       2005   2300.745820
# 5598    90021           777 E 10th St  SINGLE_FAMILY       2009   2432.110834
#
#      lotAreaUnits  livingAreaValue livingAreaUnitsShort  \
# 6            sqft        90.301716                 sqft
# 85           sqft        83.612700                 sqft
# 1186         sqft       137.403537                 sqft
# 1345         sqft       401.340960                 sqft
# 1547         sqft       137.310634                 sqft
# ...           ...              ...                  ...
# 5556         sqft       718.790511                 sqft
# 5570        Acres      8004.986995                 sqft
# 5581        Acres      2709.608898                 sqft
# 5597        Acres      4059.954003                 sqft
# 5598        Acres      8584.330103                 sqft
#
#       garageParkingCapacity  bedrooms  ...  currency  parkingCapacity  \
# 6                       NaN       2.0  ...       USD                0
# 85                      NaN       2.0  ...       USD                2
# 1186                    2.0       3.0  ...       USD                2
# 1345                    0.0       6.0  ...       USD                0
# 1547                    2.0       3.0  ...       USD                2
# ...                     ...       ...  ...       ...              ...
# 5556                    NaN       4.0  ...       USD                2
# 5570                    NaN       NaN  ...       USD                0
# 5581                    NaN       6.0  ...       USD                0
# 5597                    NaN       NaN  ...       USD                0
# 5598                    NaN       NaN  ...       USD                0
#
#       hasCooling hasHeating hasFireplace hasPrivatePool hasSpa hasView  \
# 6           True       True          NaN            NaN  False   False
# 85          True       True         True            NaN  False    True
# 1186        True       True        False            NaN  False    True
# 1345         NaN        NaN          NaN            NaN  False   False
# 1547        True       True        False            NaN  False    True
# ...          ...        ...          ...            ...    ...     ...
# 5556        True       True         True            NaN  False    True
# 5570        True      False          NaN            NaN  False   False
# 5581        True      False          NaN            NaN  False   False
# 5597       False      False          NaN            NaN  False   False
# 5598        True      False          NaN            NaN  False   False
#
#                                        securityFeatures Unnamed: 38
# 6                                                   NaN         NaN
# 85                                                  NaN         NaN
# 1186                                                NaN         NaN
# 1345                                                NaN         NaN
# 1547                                                NaN         NaN
# ...                                                 ...         ...
# 5556  ['Security System Owned', 'Security Lights', '...         NaN
# 5570                                                NaN         NaN
# 5581                                                NaN         NaN
# 5597                                                NaN         NaN
# 5598                                                NaN         NaN
#
# [115 rows x 36 columns]

# %%
df.loc[df['livingAreaValue'] > df['lotAreaValue'], 'lotAreaValue'] = df['livingAreaValue']

# %%
df[(df["lotAreaValue"] < df["livingAreaValue"]) & (df["lotAreaValue"] > 0.1)]
# Out:
# Empty DataFrame
# Columns: [zipcode, streetAddress, homeType, yearBuilt, lotAreaValue, lotAreaUnits, livingAreaValue, livingAreaUnitsShort, garageParkingCapacity, bedrooms, bathrooms, bathroomsFull, stories, flooring, foundationDetails, heating, cooling, fireplaceFeatures, sewer, roofType, taxAssessedValue, zestimate, rentZestimate, sold-history, pricePerSquareFoot, price, currency, parkingCapacity, hasCooling, hasHeating, hasFireplace, hasPrivatePool, hasSpa, hasView, securityFeatures, Unnamed: 38]
# Index: []
#
# [0 rows x 36 columns]

# %% [markdown]
# We also replace the living area values that are less than a threshold with the lot area of the house.

# %%
df[(df["livingAreaValue"] < 1)]
# Out:
#       zipcode             streetAddress       homeType  yearBuilt  \
# 439     90011       1626-1628 E 32nd St   MULTI_FAMILY       1905
# 1955    91402           9146 Willis Ave  SINGLE_FAMILY       1976
# 3762    90016          2923 S Orange Dr   MULTI_FAMILY       1922
# 4495    90029           909 Sanborn Ave  SINGLE_FAMILY       1922
# 4587    90026        1321 Edgecliffe Dr  SINGLE_FAMILY       2023
# 4656    90026        1323 Edgecliffe Dr  SINGLE_FAMILY       2023
# 4687    90037             211 W 43rd St   MULTI_FAMILY       2021
# 5346    90210          9625 Oak Pass Rd  SINGLE_FAMILY       1974
# 5552    90210  2859 Coldwater Canyon Dr  SINGLE_FAMILY       1959
# 5562    91436   15824 Valley Vista Blvd  SINGLE_FAMILY       2024
#
#       lotAreaValue lotAreaUnits  livingAreaValue livingAreaUnitsShort  \
# 439     464.886612         sqft         0.092903                 sqft
# 1955   1618.744000        Acres         0.185806                 sqft
# 3762    669.644824         sqft         0.278709                 sqft
# 4495    497.358440         sqft         0.000000                 sqft
# 4587    682.704385         sqft         0.000000                 sqft
# 4656    682.704385         sqft         0.000000                 sqft
# 4687    589.934050         sqft         0.185806                 sqft
# 5346   1855.080624        Acres         0.000000                 sqft
# 5552  12009.866422        Acres         0.000000                 sqft
# 5562   1442.300904        Acres         0.000000                 sqft
#
#       garageParkingCapacity  bedrooms  ...  currency  parkingCapacity  \
# 439                     1.0       4.0  ...       USD                1
# 1955                    NaN       4.0  ...       USD                2
# 3762                    3.0       5.0  ...       USD                9
# 4495                    0.0       2.0  ...       USD                3
# 4587                    NaN       4.0  ...       USD                2
# 4656                    NaN       4.0  ...       USD                2
# 4687                    1.0      15.0  ...       USD                6
# 5346                    NaN       4.0  ...       USD                4
# 5552                    NaN       7.0  ...       USD               20
# 5562                    NaN       5.0  ...       USD                3
#
#       hasCooling hasHeating hasFireplace hasPrivatePool hasSpa hasView  \
# 439        False       True        False            NaN  False   False
# 1955        True       True          NaN            NaN  False   False
# 3762        True       True         True            NaN  False    True
# 4495        True       True         True            NaN  False    True
# 4587        True       True         True            NaN  False    True
# 4656        True       True         True            NaN  False    True
# 4687        True       True          NaN            NaN  False   False
# 5346        True       True         True           True   True    True
# 5552        True       True         True            NaN  False    True
# 5562        True       True         True            NaN  False    True
#
#                                        securityFeatures Unnamed: 38
# 439                                                 NaN         NaN
# 1955                                                NaN         NaN
# 3762                                                NaN         NaN
# 4495  ['Exterior Security Lights', 'Gated', 'Smoke D...         NaN
# 4587                                                NaN         NaN
# 4656                                                NaN         NaN
# 4687                                                NaN         NaN
# 5346  ['Exterior Security Lights', 'Secured Communit...         NaN
# 5552                                                NaN         NaN
# 5562                                   ['Alarm System']         NaN
#
# [10 rows x 36 columns]

# %%
df.loc[df['livingAreaValue'] < 1, 'livingAreaValue'] = df['lotAreaValue']

# %% [markdown]
# We drop the units columns since we don't need them anymore.

# %%
df.drop(columns=['lotAreaUnits', 'livingAreaUnitsShort'], inplace=True)

# %%
df["garageParkingCapacity"].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 5157 entries, 0 to 5605
# Series name: garageParkingCapacity
# Non-Null Count  Dtype
# --------------  -----
# 3237 non-null   float64
# dtypes: float64(1)
# memory usage: 209.6 KB

# %% [markdown]
# ### Garage Parking Capacity
#
# We drop this column since we have too many null values and also we have another column for parking spaces.

# %%
df["garageParkingCapacity"].isna().sum()
# Out:
# 1920

# %%
df.drop(columns=["garageParkingCapacity"], inplace=True)

# %% [markdown]
# ### Bedrooms

# %% [markdown]
# We checked the values counts of the bedrooms and checked the houses with high number of bedrooms again from the website. We found out some of them were multi-family and the data was correct but some of them seemed to be wrong so we dropped them.

# %%
df["bedrooms"].value_counts()
# Out:
# bedrooms
# 3.0     1829
# 2.0     1185
# 4.0     1067
# 5.0      413
# 1.0      267
# 6.0      130
# 8.0       67
# 7.0       45
# 12.0      19
# 0.0       19
# 9.0       16
# 10.0      14
# 16.0      10
# 13.0       9
# 11.0       6
# 14.0       4
# 18.0       4
# 17.0       2
# 36.0       2
# 15.0       2
# 20.0       2
# 40.0       1
# 34.0       1
# 24.0       1
# 19.0       1
# 25.0       1
# 35.0       1
# 33.0       1
# 28.0       1
# 99.0       1
# 44.0       1
# 72.0       1
# 32.0       1
# 31.0       1
# Name: count, dtype: int64

# %%
df[df["bedrooms"] > 30].sort_values(by="bedrooms")
# Out:
#       zipcode             streetAddress       homeType  yearBuilt  \
# 5521    90034            10915 Rose Ave   MULTI_FAMILY       1971
# 510     90026             211 N Reno St      APARTMENT       1925
# 5280    91605          13135 Vanowen St   MULTI_FAMILY       1960
# 5378    90016    5110 W Washington Blvd   MULTI_FAMILY       1946
# 3634    90039        2938 Allesandro St  SINGLE_FAMILY       2022
# 5446    90006            1029 Elden Ave   MULTI_FAMILY       1991
# 5466    90003  5869-5875 S San Pedro St   MULTI_FAMILY       2023
# 5299    90044             649 W 92nd St   MULTI_FAMILY       2023
# 3699    90065      3516 Arroyo Seco Ave   MULTI_FAMILY       1964
# 3216    90011             637 E 23rd St   MULTI_FAMILY       1957
# 4329    91401           14106 Delano St   MULTI_FAMILY       1963
#
#       lotAreaValue  livingAreaValue  bedrooms  bathrooms  bathroomsFull  \
# 5521   1899.866350      1899.866350      31.0       31.0            NaN
# 510    1065.691714       992.204040      32.0       16.0            NaN
# 5280   1547.923950      1399.769501      33.0       25.0            NaN
# 5378   2207.157444      1011.249155      34.0       34.0            NaN
# 3634   3015.259768      3015.259768      35.0       35.0            NaN
# 5446   2024.263467      2024.263467      36.0       35.0            NaN
# 5466   1667.330141      1667.330141      36.0       28.0            NaN
# 5299   1765.240332      1196.590640      40.0       24.0            NaN
# 3699    761.154279       435.343458      44.0       24.0            NaN
# 3216    541.067072       327.018560      72.0       36.0            NaN
# 4329    694.728634       513.567784      99.0       99.0            NaN
#
#       stories  ... currency parkingCapacity hasCooling hasHeating  \
# 5521      NaN  ...      USD               0       True      False
# 510       NaN  ...      USD               0      False      False
# 5280      2.0  ...      USD              14       True       True
# 5378      1.0  ...      USD              14      False      False
# 3634      NaN  ...      USD               0      False      False
# 5446      3.0  ...      USD              32       True       True
# 5466      3.0  ...      USD               8       True       True
# 5299      2.0  ...      USD               0       True       True
# 3699      2.0  ...      USD               6        NaN       True
# 3216      2.0  ...      USD               0        NaN        NaN
# 4329      2.0  ...      USD               9       True       True
#
#      hasFireplace hasPrivatePool hasSpa  hasView  \
# 5521          NaN            NaN  False    False
# 510           NaN            NaN  False    False
# 5280          NaN            NaN  False    False
# 5378          NaN            NaN  False    False
# 3634          NaN            NaN  False    False
# 5446          NaN            NaN  False    False
# 5466          NaN            NaN  False     True
# 5299          NaN            NaN  False    False
# 3699          NaN            NaN  False    False
# 3216          NaN            NaN  False    False
# 4329        False            NaN  False     True
#
#                                        securityFeatures  Unnamed: 38
# 5521                                                NaN          NaN
# 510                                                 NaN          NaN
# 5280                                                NaN          NaN
# 5378                                                NaN          NaN
# 3634                                                NaN          NaN
# 5446                                                NaN          NaN
# 5466                                          ['Gated']          NaN
# 5299                                                NaN          NaN
# 3699                                                NaN          NaN
# 3216                                                NaN          NaN
# 4329  ['Automatic Gate', 'Carbon Monoxide Detector(s...          NaN
#
# [11 rows x 33 columns]

# %%
df.drop(index=[4329,510,3634,3699]	, inplace=True)

# %% [markdown]
# We also dropped the null values since they were only few.

# %%
df["bedrooms"].isna().sum()
# Out:
# 32

# %%
df.dropna(subset=["bedrooms"], inplace=True)

# %%
df["bedrooms"].isna().sum()
# Out:
# 0

# %%
df["bedrooms"] = df["bedrooms"].astype(int)

# %% [markdown]
# We checked the houses with 0 bedrooms from the website and dropped some of them that seemed to be wrong.

# %%
df[df["bedrooms"] ==0]
# Out:
#       zipcode                  streetAddress       homeType  yearBuilt  \
# 136     90015                 1421 Albany St  SINGLE_FAMILY       1903
# 238     91316    5325 Newcastle Ave UNIT 128          CONDO       1971
# 315     90012          800 W 1st St APT 1604          CONDO       1968
# 341     90015           645 W 9th St APT 405          CONDO       2006
# 360     90031  200 N San Fernando Rd APT 211          CONDO       1925
# 371     90046     7250 Franklin Ave UNIT 711          CONDO       1964
# 379     90013           825 E 4th St APT 109          CONDO       1923
# 383     90012         257 S Spring St APT 4L          CONDO       1899
# 387     90014          215 W 7th St APT 1303          CONDO       1911
# 409     90013     420 S San Pedro St APT 213          CONDO       1922
# 468     90731           285 W 6th St APT 310          CONDO       2006
# 471     90014  746 S Los Angeles St APT 1103          CONDO       1922
# 477     90005      620 S Gramercy Pl APT 431          CONDO       1990
# 493     90017       877 Francisco St APT 819          CONDO       2017
# 576     90028            1645 N Vine St #501          CONDO       1928
# 596     90037                  829 W 56th St  SINGLE_FAMILY       1922
# 1260    91406                  15322 Hart St            LOT       1938
# 2872    90013       510 S Hewitt St UNIT 515          CONDO       1966
# 4530    91042             7157 Foothill Blvd  SINGLE_FAMILY       1947
#
#       lotAreaValue  livingAreaValue  bedrooms  bathrooms  bathroomsFull  \
# 136   5.584399e+02       190.544053         0        0.0            0.0
# 238   9.585393e+03        44.872149         0        1.0            1.0
# 315   9.874338e+03        44.686343         0        1.0            1.0
# 341   6.943602e+03        61.315980         0        1.0            1.0
# 360   5.868352e+03        62.245010         0        1.0            1.0
# 371   4.973186e+03        49.796008         0        1.0            1.0
# 379   4.011652e+03        61.315980         0        1.0            1.0
# 383   2.677403e+03        60.386950         0        1.0            1.0
# 387   1.479575e+03        58.528890         0        1.0            1.0
# 409   7.099002e+03        72.464340         0        1.0            1.0
# 468   5.621089e+03        77.109490         0        1.0            1.0
# 471   3.558809e+03        71.535310         0        1.0            1.0
# 477   4.789459e+03        55.927606         0        1.0            1.0
# 493   1.198073e+04        47.473433         0        1.0            1.0
# 576   2.091013e+03        99.406210         0        1.0            1.0
# 596   4.756634e+02       157.563488         0        0.0            NaN
# 1260  6.503210e+02       189.150508         0        0.0            0.0
# 2872  2.164665e+03       123.560990         0        1.0            1.0
# 4530  5.495231e+07       451.880192         0        0.0            NaN
#
#       stories  ... currency parkingCapacity hasCooling hasHeating  \
# 136       NaN  ...      USD               6      False       True
# 238       1.0  ...      USD               1       True       True
# 315       NaN  ...      USD               1       True        NaN
# 341       1.0  ...      USD               1       True       True
# 360       NaN  ...      USD               1       True       True
# 371       NaN  ...      USD               1       True       True
# 379       6.0  ...      USD               1       True       True
# 383       5.0  ...      USD               1       True       True
# 387       1.0  ...      USD               0       True       True
# 409       6.0  ...      USD               1       True       True
# 468       1.0  ...      USD               4       True       True
# 471      11.0  ...      USD               1       True       True
# 477       NaN  ...      USD               1       True       True
# 493       NaN  ...      USD               1       True       True
# 576      11.0  ...      USD               1       True       True
# 596       NaN  ...      USD               0      False      False
# 1260      NaN  ...      USD               1      False      False
# 2872      NaN  ...      USD               1       True       True
# 4530      NaN  ...      USD               0        NaN        NaN
#
#      hasFireplace hasPrivatePool hasSpa  hasView  \
# 136           NaN            NaN  False    False
# 238          True            NaN  False     True
# 315         False            NaN  False    False
# 341         False            NaN   True     True
# 360         False            NaN  False     True
# 371         False            NaN  False     True
# 379         False            NaN  False     True
# 383         False            NaN  False     True
# 387         False            NaN  False     True
# 409         False            NaN  False     True
# 468         False            NaN  False     True
# 471         False            NaN  False     True
# 477          True            NaN  False     True
# 493         False            NaN  False     True
# 576         False            NaN  False     True
# 596           NaN            NaN  False    False
# 1260          NaN            NaN  False    False
# 2872        False            NaN  False     True
# 4530          NaN            NaN  False    False
#
#                                        securityFeatures  Unnamed: 38
# 136                                                 NaN          NaN
# 238                                                 NaN          NaN
# 315                                                 NaN          NaN
# 341                                                 NaN          NaN
# 360   ['Card/Code Access', 'Carbon Monoxide Detector...          NaN
# 371                                ['24 Hour Security']          NaN
# 379   ['Automatic Gate', 'Carbon Monoxide Detector(s...          NaN
# 383   ['Gated with Guard', 'Gated', 'Other', 'Card/C...          NaN
# 387   ['24 Hour Security', 'Gated with Attendant', '...          NaN
# 409   ['24 Hour Security', 'Security Lights', 'Fire ...          NaN
# 468             ['Card/Code Access', 'Gated Community']          NaN
# 471   ['Card/Code Access', 'Carbon Monoxide Detector...          NaN
# 477                       ['24 Hour Security', 'Gated']          NaN
# 493   ['24 Hour Security', 'Automatic Gate', 'Card/C...          NaN
# 576                     ['24 Hour Security', 'Guarded']          NaN
# 596                                                 NaN          NaN
# 1260                                                NaN          NaN
# 2872                               ['24 Hour Security']          NaN
# 4530                                                NaN          NaN
#
# [19 rows x 33 columns]

# %%
df.drop(index=[136,596,4530], inplace=True)

# %% [markdown]
# ### Bathrooms

# %% [markdown]
# We drop the null values since they were only few.

# %%
df["bathrooms"].isna().sum()
# Out:
# 11

# %%
df.dropna(subset=["bathrooms"], inplace=True)

# %% [markdown]
# We also drop the houses with 0 bathrooms unless they are LOT(land).

# %%
df[df["bathrooms"] == 0]
# Out:
#       zipcode       streetAddress      homeType  yearBuilt  lotAreaValue  \
# 235     90003      6007 S Main St  MULTI_FAMILY       1911    526.016786
# 460     90032     4502 Lowell Ave           LOT       1922    695.564761
# 1260    91406       15322 Hart St           LOT       1938    650.321000
# 1876    91405  6826 Hazeltine Ave           LOT       1946    488.019459
# 1901    90063    520 S Concord St  MULTI_FAMILY       1917    538.187079
# 2245    90044  624 W Imperial Hwy           LOT       1939    822.284453
# 3118    90018      2216 S 8th Ave  MULTI_FAMILY       2008    464.515000
# 3650    91601    11343 Miranda St           LOT       1923   1275.559867
# 3860    90044  8886 S Vermont Ave           LOT       1951    997.127899
# 4459    91436  16879 Mooncrest Dr           LOT       1955   1022.213053
# 5322    90027   2718 Hyperion Ave  MULTI_FAMILY       1918   2150.893084
#
#       livingAreaValue  bedrooms  bathrooms  bathroomsFull  stories  ...  \
# 235        163.137668         5        0.0            NaN      NaN  ...
# 460         58.435987         2        0.0            0.0      NaN  ...
# 1260       189.150508         0        0.0            0.0      NaN  ...
# 1876        64.846294         2        0.0            0.0      NaN  ...
# 1901       125.976468         4        0.0            0.0      NaN  ...
# 2245       161.279608         5        0.0            0.0      NaN  ...
# 3118       213.676900         8        0.0            0.0      NaN  ...
# 3650       109.625540         3        0.0            0.0      NaN  ...
# 3860       206.058854         2        0.0            0.0      NaN  ...
# 4459       157.935100         2        0.0            0.0      NaN  ...
# 5322       313.733431         5        0.0            3.0      NaN  ...
#
#      currency parkingCapacity hasCooling hasHeating hasFireplace  \
# 235       USD               0      False      False          NaN
# 460       USD               1      False       True          NaN
# 1260      USD               1      False      False          NaN
# 1876      USD               1      False      False          NaN
# 1901      USD               0      False      False        False
# 2245      USD               0      False       True          NaN
# 3118      USD               6      False       True          NaN
# 3650      USD               0      False      False          NaN
# 3860      USD              10      False       True          NaN
# 4459      USD               2       True       True          NaN
# 5322      USD               4      False       True        False
#
#      hasPrivatePool hasSpa  hasView  securityFeatures  Unnamed: 38
# 235             NaN  False    False               NaN          NaN
# 460             NaN  False    False               NaN          NaN
# 1260            NaN  False    False               NaN          NaN
# 1876            NaN  False    False               NaN          NaN
# 1901            NaN  False     True               NaN          NaN
# 2245            NaN  False    False               NaN          NaN
# 3118            NaN  False    False               NaN          NaN
# 3650            NaN  False    False               NaN          NaN
# 3860            NaN  False    False               NaN          NaN
# 4459            NaN  False    False               NaN          NaN
# 5322            NaN  False    False               NaN          NaN
#
# [11 rows x 33 columns]

# %%
df = df[(df["bathrooms"] != 0) | (df["homeType"] == "LOT")]

# %% [markdown]
# ### Bathrooms Full

# %% [markdown]
# We dropped this column since it had too many null values and also we have another column for bathrooms.

# %%
df["bathroomsFull"].isna().sum()
# Out:
# 749

# %%
df.drop(columns=["bathroomsFull"], inplace=True)

# %% [markdown]
# ### Stories

# %% [markdown]
# Stories is the number of floors in the house.

# %%
df["stories"].value_counts()
# Out:
# stories
# 1.0     2325
# 2.0     1173
# 3.0      385
# 4.0      116
# 5.0       27
# 22.0      12
# 6.0       11
# 13.0       8
# 18.0       6
# 8.0        6
# 23.0       6
# 11.0       5
# 16.0       4
# 24.0       4
# 19.0       4
# 21.0       4
# 10.0       3
# 14.0       3
# 7.0        3
# 15.0       2
# 17.0       2
# 20.0       2
# 32.0       2
# 29.0       2
# 27.0       2
# 25.0       1
# 39.0       1
# 28.0       1
# 52.0       1
# 54.0       1
# 42.0       1
# Name: count, dtype: int64

# %% [markdown]
# We fill LOT stories with 0.

# %%
df[(df["stories"].isna())&(df["homeType"]=="LOT")]
# Out:
#       zipcode       streetAddress homeType  yearBuilt  lotAreaValue  \
# 460     90032     4502 Lowell Ave      LOT       1922    695.564761
# 1260    91406       15322 Hart St      LOT       1938    650.321000
# 1876    91405  6826 Hazeltine Ave      LOT       1946    488.019459
# 2245    90044  624 W Imperial Hwy      LOT       1939    822.284453
# 3650    91601    11343 Miranda St      LOT       1923   1275.559867
# 3860    90044  8886 S Vermont Ave      LOT       1951    997.127899
# 4459    91436  16879 Mooncrest Dr      LOT       1955   1022.213053
#
#       livingAreaValue  bedrooms  bathrooms  stories   flooring  ... currency  \
# 460         58.435987         2        0.0      NaN         []  ...      USD
# 1260       189.150508         0        0.0      NaN         []  ...      USD
# 1876        64.846294         2        0.0      NaN         []  ...      USD
# 2245       161.279608         5        0.0      NaN         []  ...      USD
# 3650       109.625540         3        0.0      NaN         []  ...      USD
# 3860       206.058854         2        0.0      NaN  ['Other']  ...      USD
# 4459       157.935100         2        0.0      NaN  ['Other']  ...      USD
#
#      parkingCapacity hasCooling hasHeating hasFireplace hasPrivatePool  \
# 460                1      False       True          NaN            NaN
# 1260               1      False      False          NaN            NaN
# 1876               1      False      False          NaN            NaN
# 2245               0      False       True          NaN            NaN
# 3650               0      False      False          NaN            NaN
# 3860              10      False       True          NaN            NaN
# 4459               2       True       True          NaN            NaN
#
#       hasSpa  hasView  securityFeatures Unnamed: 38
# 460    False    False               NaN         NaN
# 1260   False    False               NaN         NaN
# 1876   False    False               NaN         NaN
# 2245   False    False               NaN         NaN
# 3650   False    False               NaN         NaN
# 3860   False    False               NaN         NaN
# 4459   False    False               NaN         NaN
#
# [7 rows x 32 columns]

# %%
df.loc[(df["homeType"]=="LOT"), "stories"] = 0

# %%
df["stories"].isna().sum()
# Out:
# 973

# %% [markdown]
# We fill the other null values with the most frequent value which is 1.

# %%
df[df["stories"].isna()]["homeType"].value_counts()
# Out:
# homeType
# SINGLE_FAMILY    532
# CONDO            256
# MULTI_FAMILY     124
# TOWNHOUSE         36
# APARTMENT         22
# MANUFACTURED       3
# Name: count, dtype: int64

# %%
df['stories'] = df["stories"].fillna(1)

# %% [markdown]
# ### Array-like columns

# %% [markdown]
# Some of the columns are arrays of values so the first thing we do is to convert them from string to a real array and also we group some of the values to one value.

# %% [markdown]
# #### Flooring

# %%
df["flooring"].value_counts()
# Out:
# flooring
# []                                                        419
# ['Wood']                                                  278
# ['Hardwood']                                              267
# ['Laminate']                                              253
# ['Tile', 'Wood']                                          150
#                                                          ...
# ['Stone', 'Engineered Hardwood', 'Hardwood']                1
# ['Linoleum', 'Wood', 'Tile']                                1
# ['Vinyl Plank', 'Engineered Hardwood', 'Ceramic Tile']      1
# ['Hardwood', 'Terrazzo', 'Laminate']                        1
# ['Tile', 'Hardwood', 'Stone', 'Stone Tile']                 1
# Name: count, Length: 580, dtype: int64

# %%
df["flooring"] = df["flooring"].fillna("[]")

# %%
import ast
df['flooring'] = df['flooring'].apply(ast.literal_eval)

# %%
all_values = [item for sublist in df['flooring'] for item in sublist]
unique_values = set(all_values)
unique_values
# Out:
# {'Bamboo',
#  'Brick',
#  'Carpet',
#  'Cement',
#  'Ceramic Tile',
#  'Clay',
#  'Concrete',
#  'Engineered Hardwood',
#  'Granite',
#  'Hardwood',
#  'Hardwood Flrs Throughout',
#  'In Need Of Repair',
#  'Laminate',
#  'Linoleum',
#  'Linoleum / Vinyl',
#  'Marble',
#  'Mixed',
#  'Other',
#  'Parquet',
#  'Pavers',
#  'Porcelain',
#  'See Remarks',
#  'Slate',
#  'Stained Concrete',
#  'Stone',
#  'Stone Tile',
#  'Terrazzo',
#  'Tile',
#  'Travertine',
#  'Vinyl',
#  'Vinyl Plank',
#  'Vinyl Sheet',
#  'Vinyl Tile',
#  'Wood',
#  'Wood Laminate',
#  'Wood Under Carpet'}

# %%
df['flooring'] = df['flooring'].apply(lambda x: ['Hardwood' if item in ['Hardwood Flrs Throughout'] else item for item in x])
df['flooring'] = df['flooring'].apply(lambda x: ['Linoleum' if item in ['Linoleum / Vinyl'] else item for item in x])
df['flooring'] = df['flooring'].apply(lambda x: ['Vinyl' if item in ['Vinyl Plank','Vinyl Sheet','Vinyl Tile'] else item for item in x])
df['flooring'] = df['flooring'].apply(lambda x: ['Wood' if item in ['Wood Laminate','Wood Under Carpet','Hardwood','Engineered Hardwood'] else item for item in x])
df['flooring'] = df['flooring'].apply(lambda x: ['Stone' if item in ['Stone Tile'] else item for item in x])
df['flooring'] = df['flooring'].apply(lambda x: ['Concrete' if item in ['Stained Concrete'] else item for item in x])
df['flooring'] = df['flooring'].apply(lambda x: ['Tile' if item in [ 'Ceramic Tile'] else item for item in x])
df['flooring'] = df['flooring'].apply(lambda x: [item for item in x if item != 'See Remarks'])

all_values = [item for sublist in df['flooring'] for item in sublist]
unique_values = set(all_values)
unique_values
# Out:
# {'Bamboo',
#  'Brick',
#  'Carpet',
#  'Cement',
#  'Clay',
#  'Concrete',
#  'Granite',
#  'In Need Of Repair',
#  'Laminate',
#  'Linoleum',
#  'Marble',
#  'Mixed',
#  'Other',
#  'Parquet',
#  'Pavers',
#  'Porcelain',
#  'Slate',
#  'Stone',
#  'Terrazzo',
#  'Tile',
#  'Travertine',
#  'Vinyl',
#  'Wood'}

# %%
#check how may flooring is empty
df[df["flooring"].apply(len) == 0]
# Out:
#       zipcode             streetAddress       homeType  yearBuilt  \
# 6       91303    7305 Milwood Ave APT 3          CONDO       1981
# 8       91040          8701 Hillrose St  SINGLE_FAMILY       1945
# 10      91325  17123 Roscoe Blvd UNIT 2      APARTMENT       1971
# 12      91605      7920 Saint Clair Ave  SINGLE_FAMILY       1948
# 24      91601            5738 Denny Ave  SINGLE_FAMILY       1975
# ...       ...                       ...            ...        ...
# 5559    90272            1117 Kagawa St  SINGLE_FAMILY       2007
# 5566    90049      12319 18th Helena Dr  SINGLE_FAMILY       1948
# 5581    90004          4804 Oakwood Ave      APARTMENT       2022
# 5583    90069       1896 Rising Glen Rd  SINGLE_FAMILY       1959
# 5600    91436           4550 Libbit Ave  SINGLE_FAMILY       1951
#
#       lotAreaValue  livingAreaValue  bedrooms  bathrooms  stories flooring  \
# 6        90.301716        90.301716         2        1.0      1.0       []
# 8      7098.170143       129.320976         2        1.5      1.0       []
# 10    30031.677454       127.091304         3        2.0      1.0       []
# 12      724.364691        88.257850         2        2.0      1.0       []
# 24      930.702254       125.419050         3        2.0      1.0       []
# ...            ...              ...       ...        ...      ...      ...
# 5559    603.869500       320.608253         5        6.0      1.0       []
# 5566   1263.389558       181.532462         2        2.0      1.0       []
# 5581   2709.608898      2709.608898         6        4.0      1.0       []
# 5583   5948.865619       420.757687         4        5.0      1.0       []
# 5600   3829.559597       415.740925         5        5.0      1.0       []
#
#       ... currency parkingCapacity hasCooling hasHeating hasFireplace  \
# 6     ...      USD               0       True       True          NaN
# 8     ...      USD               2      False      False          NaN
# 10    ...      USD               2       True       True         True
# 12    ...      USD               0      False      False          NaN
# 24    ...      USD               1      False       True          NaN
# ...   ...      ...             ...        ...        ...          ...
# 5559  ...      USD               1       True       True          NaN
# 5566  ...      USD               2      False       True         True
# 5581  ...      USD               0       True      False          NaN
# 5583  ...      USD               4       True       True          NaN
# 5600  ...      USD               1       True       True          NaN
#
#      hasPrivatePool  hasSpa  hasView  securityFeatures Unnamed: 38
# 6               NaN   False    False               NaN         NaN
# 8               NaN   False    False               NaN         NaN
# 10              NaN   False    False               NaN         NaN
# 12              NaN   False    False               NaN         NaN
# 24              NaN   False    False               NaN         NaN
# ...             ...     ...      ...               ...         ...
# 5559            NaN   False    False               NaN         NaN
# 5566            NaN   False    False               NaN         NaN
# 5581            NaN   False    False               NaN         NaN
# 5583            NaN   False     True               NaN         NaN
# 5600            NaN   False    False               NaN         NaN
#
# [1776 rows x 32 columns]

# %% [markdown]
# #### Heating

# %%
df["heating"].isna().sum()
# Out:
# 454

# %%
df["heating"] = df["heating"].fillna("[]")

# %%
import ast
df['heating']=df['heating'].apply(ast.literal_eval)

# %%
all_values = [item for sublist in df['heating'] for item in sublist]
unique_values = set(all_values)
unique_values
# Out:
# {'Baseboard',
#  'Central',
#  'Central Forced Air',
#  'Central Heat/Gas',
#  'Combination',
#  'Ductless',
#  'ENERGY STAR Qualified Equipment',
#  'Electric',
#  'Fireplace(s)',
#  'Floor Furnace',
#  'Forced Air',
#  'Forced air',
#  'Gas',
#  'Geothermal',
#  'Gravity',
#  'Has Heating (Unspecified Type)',
#  'Heat Pump',
#  'Heat pump',
#  'High Efficiency',
#  'Hot Water',
#  'Natural Gas',
#  'None',
#  'Other',
#  'Other Heat Source (See Remarks)',
#  'Passive Solar',
#  'Propane',
#  'Radiant',
#  'See Remarks',
#  'Solar',
#  'Solar Heat Other',
#  'Space Heater',
#  'Stove',
#  'Wall',
#  'Wall Electric',
#  'Wall Furnace',
#  'Wall Gas',
#  'Wood',
#  'Zoned',
#  'central',
#  'wood'}

# %%
df['heating'] = df['heating'].apply(lambda x: ['Central' if item in ['Central Forced Air','Central Heat/Gas','central'] else item for item in x])
df['heating'] = df['heating'].apply(lambda x: ['Forced Air' if item in ['Forced air'] else item for item in x])
df['heating'] = df['heating'].apply(lambda x: ['Heat Pump' if item in ['Heat pump'] else item for item in x])
df['heating'] = df['heating'].apply(lambda x: ['Wall' if item in ['Wall Electric','Wall Furnace','Wall Gas'] else item for item in x])
df['heating'] = df['heating'].apply(lambda x: ['Other' if item in ['Other Heat Source (See Remarks)','Has Heating (Unspecified Type)'] else item for item in x])
df['heating'] = df['heating'].apply(lambda x: ['Wood' if item in ['wood'] else item for item in x])
df['heating'] = df['heating'].apply(lambda x: ['Solar' if item in ['Solar Heat Other','Passive Solar'] else item for item in x])
df['heating'] = df['heating'].apply(lambda x: [item for item in x if item != 'See Remarks'])
all_values = [item for sublist in df['heating'] for item in sublist]
unique_values = set(all_values)
unique_values
# Out:
# {'Baseboard',
#  'Central',
#  'Combination',
#  'Ductless',
#  'ENERGY STAR Qualified Equipment',
#  'Electric',
#  'Fireplace(s)',
#  'Floor Furnace',
#  'Forced Air',
#  'Gas',
#  'Geothermal',
#  'Gravity',
#  'Heat Pump',
#  'High Efficiency',
#  'Hot Water',
#  'Natural Gas',
#  'None',
#  'Other',
#  'Propane',
#  'Radiant',
#  'Solar',
#  'Space Heater',
#  'Stove',
#  'Wall',
#  'Wood',
#  'Zoned'}

# %% [markdown]
# #### Foundation Details

# %% [markdown]
# We dropped this column because it had too many empty values.

# %%
df[df["foundationDetails"] == '[]'].shape
# Out:
# (4365, 32)

# %%
df.drop(columns=["foundationDetails"], inplace=True)

# %% [markdown]
# #### Cooling

# %%
df["cooling"].isna().sum()
# Out:
# 104

# %%
df["cooling"] = df["cooling"].fillna("[]")

# %%
import ast
df['cooling']=df['cooling'].apply(ast.literal_eval)

# %%
all_values = [item for sublist in df['cooling'] for item in sublist]
unique_values = set(all_values)
unique_values
# Out:
# {'Air Conditioning',
#  'Attic Fan',
#  'Ceiling Fan(s)',
#  'Central',
#  'Central Air',
#  'Central Air/Evap',
#  'Central Air/Refrig',
#  'Central Forced Air',
#  'Dual',
#  'Ductless',
#  'ENERGY STAR Qualified Equipment',
#  'Electric',
#  'Evaporative',
#  'Evaporative Cooling',
#  'Gas',
#  'Heat Pump',
#  'High Efficiency',
#  'None',
#  'Other',
#  'Refridge Wall/Window',
#  'Refrigerator',
#  'SEER Rated 13-15',
#  'SEER Rated 16+',
#  'See Remarks',
#  'Solar',
#  'Swamp Cooler(s)',
#  'Wall',
#  'Wall A/C Units',
#  'Wall Unit(s)',
#  'Wall/Window Unit(s)',
#  'Whole House Fan',
#  'Window Unit(s)',
#  'Zoned'}

# %%
df['cooling'] = df['cooling'].apply(lambda x: ['Central' if item in ['Central Air', 'Central Air/Evap','Central Air/Refrig','Central Forced Air'] else item for item in x])
df['cooling'] = df['cooling'].apply(lambda x: ['Evaporative' if item in ['Evaporative Cooling'] else item for item in x])
df['cooling'] = df['cooling'].apply(lambda x: ['SEER Rated' if item in ['SEER Rated 13-15','SEER Rated 16+'] else item for item in x])
df['cooling'] = df['cooling'].apply(lambda x: ['Wall' if item in ['Wall A/C Units','Wall Unit(s)','Wall/Window Unit(s)'] else item for item in x])
df['cooling'] = df['cooling'].apply(lambda x: [item for item in x if item != 'See Remarks'])
all_values = [item for sublist in df['cooling'] for item in sublist]
unique_values = set(all_values)
unique_values
# Out:
# {'Air Conditioning',
#  'Attic Fan',
#  'Ceiling Fan(s)',
#  'Central',
#  'Dual',
#  'Ductless',
#  'ENERGY STAR Qualified Equipment',
#  'Electric',
#  'Evaporative',
#  'Gas',
#  'Heat Pump',
#  'High Efficiency',
#  'None',
#  'Other',
#  'Refridge Wall/Window',
#  'Refrigerator',
#  'SEER Rated',
#  'Solar',
#  'Swamp Cooler(s)',
#  'Wall',
#  'Whole House Fan',
#  'Window Unit(s)',
#  'Zoned'}

# %% [markdown]
# #### Fireplace Features

# %%
df["fireplaceFeatures"].isna().sum()
# Out:
# 863

# %%
df["fireplaceFeatures"].value_counts()
# Out:
# fireplaceFeatures
# ['None']                                                                   1488
# ['Living Room']                                                            1116
# ['Family Room']                                                             214
# ['Living Room', 'Gas']                                                      130
# ['Decorative']                                                               86
#                                                                            ...
# ['Den', 'Family Room', 'Master Bedroom', 'Gas Starter', 'Wood Burning']       1
# ['Raised Hearth', 'Wood Burning', 'Living Room']                              1
# ['None', 'Family Room']                                                       1
# ['Outside', 'Fire Pit']                                                       1
# ['Master Bedroom', 'Gas', 'Family Room', 'Outside']                           1
# Name: count, Length: 432, dtype: int64

# %%
df["fireplaceFeatures"].fillna("[]", inplace=True)
# Out:
# C:\Users\ALI\AppData\Local\Temp\ipykernel_23920\3311353336.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["fireplaceFeatures"].fillna("[]", inplace=True)

# %%
import ast
df['fireplaceFeatures']=df['fireplaceFeatures'].apply(ast.literal_eval)

# %%
all_values = [item for sublist in df['fireplaceFeatures'] for item in sublist]
unique_values = set(all_values)
unique_values
# Out:
# {'Bath',
#  'Blower Fan',
#  'Bonus Room',
#  'Circular',
#  'Decorative',
#  'Deleted At Main Hous',
#  'Den',
#  'Dining Room',
#  'Double Sided',
#  'Electric',
#  'Family Room',
#  'Fire Pit',
#  'Free Standing',
#  'Game Room',
#  'Gas',
#  'Gas Starter',
#  'Gas and Wood',
#  'Great Room',
#  'Guest House',
#  'Heatilator',
#  'Kitchen',
#  'Library',
#  'Living Room',
#  'Masonry',
#  'Master Bedroom',
#  'Master Retreat',
#  'None',
#  'Other',
#  'Other/Remarks',
#  'Outside',
#  'Patio',
#  'Propane',
#  'Raised Hearth',
#  'See Remarks',
#  'See Through',
#  'Wood Burning',
#  'Wood Stove Insert',
#  'Woodburning'}

# %%
values_to_remove = {'None', 'See Remarks','See Through','Deleted At Main Hous'}

def remove_values(lst, values_to_remove):
    return [item for item in lst if item not in values_to_remove]

# Apply the function to the DataFrame column
df['fireplaceFeatures'] = df['fireplaceFeatures'].apply(lambda x: remove_values(x, values_to_remove))

# %%
df['fireplaceFeatures'] = df['fireplaceFeatures'].apply(lambda x: ['Gas' if item in ['Gas and Wood', 'Gas Starter'] else item for item in x])
all_values = [item for sublist in df['fireplaceFeatures'] for item in sublist]
unique_values = set(all_values)
unique_values
# Out:
# {'Bath',
#  'Blower Fan',
#  'Bonus Room',
#  'Circular',
#  'Decorative',
#  'Den',
#  'Dining Room',
#  'Double Sided',
#  'Electric',
#  'Family Room',
#  'Fire Pit',
#  'Free Standing',
#  'Game Room',
#  'Gas',
#  'Great Room',
#  'Guest House',
#  'Heatilator',
#  'Kitchen',
#  'Library',
#  'Living Room',
#  'Masonry',
#  'Master Bedroom',
#  'Master Retreat',
#  'Other',
#  'Other/Remarks',
#  'Outside',
#  'Patio',
#  'Propane',
#  'Raised Hearth',
#  'Wood Burning',
#  'Wood Stove Insert',
#  'Woodburning'}

# %% [markdown]
# #### Sewer, roofType

# %% [markdown]
# We dropped these columns too.

# %%
df['sewer'].isna().sum()
# Out:
# 2100

# %%
df.drop(columns=["sewer"], inplace=True)

# %%
df["roofType"].isna().sum()
# Out:
# 3889

# %%
df.drop(columns=["roofType"], inplace=True)

# %% [markdown]
# ### Tax Assesed Value

# %% [markdown]
# We filled the missing values of these columns with knn imputer.

# %% [markdown]
# We have used `KNNImputer` To handle missing values in a dataset by imputing them based on the values of the nearest neighbors. The imputation is done by identifying the 'k' nearest neighbors for each data point with missing values, and then using the values from these neighbors to estimate and fill in the missing values. Since the imputation is based on similar data points, it often provides more accurate and meaningful imputations compared to simpler methods like mean or median imputation.

# %%
from sklearn.impute import KNNImputer

def fill_na_with_knn(data, column_name, n_neighbors=5):
    data_copy = data.copy()
    imputer = KNNImputer(n_neighbors=n_neighbors)
    numeric_data = data_copy.select_dtypes(include=[float, int])
    imputed_data = imputer.fit_transform(numeric_data)
    data_copy[column_name] = imputed_data[:, numeric_data.columns.get_loc(column_name)]
    return data_copy

# %%
df["taxAssessedValue"].isna().sum()
# Out:
# 275

# %%
df["taxAssessedValue"].describe()
# Out:
# count    4.828000e+03
# mean     7.943156e+05
# std      1.150392e+06
# min      9.010000e+03
# 25%      2.485928e+05
# 50%      5.270865e+05
# 75%      9.047890e+05
# max      2.264544e+07
# Name: taxAssessedValue, dtype: float64

# %%
df = fill_na_with_knn(df,"taxAssessedValue",5)

# %%
df["taxAssessedValue"].isna().sum()
# Out:
# 0

# %% [markdown]
# ### Zestimate

# %% [markdown]
# We keep the zestimate null values because they are simply an estimation of the house price from zillow and they are not data from real world.

# %%
df["zestimate"].isna().sum()
# Out:
# 254

# %% [markdown]
# ### Rent Zestimate

# %%
df["rentZestimate"].isna().sum()
# Out:
# 0

# %% [markdown]
# ### Sold-history
# Which is another array-like column.

# %%
df["sold-history"].isna().sum()
# Out:
# 0

# %%
df[df["sold-history"]=="[]"]
# Out:
#       zipcode           streetAddress       homeType  yearBuilt  lotAreaValue  \
# 17      90035       1574 Glenville Dr  SINGLE_FAMILY       1929  3.738417e+02
# 36      91344      17237 Kingsbury St  SINGLE_FAMILY       1959  3.722623e+02
# 38      91335      7317 White Oak Ave  SINGLE_FAMILY       1951  2.225773e+07
# 62      90025  1813 Thayer Ave UNIT E      APARTMENT       2008  5.339135e+02
# 80      90045          6531 W 85th St  SINGLE_FAMILY       1943  5.655935e+02
# ...       ...                     ...            ...        ...           ...
# 5580    90210    11 Beverly Ridge Ter  SINGLE_FAMILY       2006  1.268852e+04
# 5581    90004        4804 Oakwood Ave      APARTMENT       2022  2.709609e+03
# 5591    90272        1457 San Remo Dr  SINGLE_FAMILY       1953  1.939255e+03
# 5593    90049          1498 Moraga Dr  SINGLE_FAMILY       1981  2.243174e+03
# 5601    90077            825 Nimes Pl  SINGLE_FAMILY       1952  2.832337e+03
#
#       livingAreaValue  bedrooms  bathrooms  stories  \
# 17          74.322400         1        1.0      1.0
# 36          74.322400         2        2.0      1.0
# 38          47.566336         2        1.0      1.0
# 62         173.728610         3        2.5      1.0
# 80         116.128750         2        1.0      1.0
# ...               ...       ...        ...      ...
# 5580      1209.039642         6       10.0      2.0
# 5581      2709.608898         6        4.0      1.0
# 5591       417.041567         5        5.0      1.0
# 5593       990.810495         6        7.0      2.0
# 5601       557.418000         5        6.0      1.0
#
#                          flooring  ... currency parkingCapacity hasCooling  \
# 17                 [Carpet, Wood]  ...      USD               1      False
# 36               [Tile, Laminate]  ...      USD               2       True
# 38                             []  ...      USD               0        NaN
# 62                         [Wood]  ...      USD               0       True
# 80                             []  ...      USD               2       True
# ...                           ...  ...      ...             ...        ...
# 5580          [Wood, Stone, Wood]  ...      USD               7       True
# 5581                           []  ...      USD               0       True
# 5591               [Wood, Carpet]  ...      USD               2       True
# 5593  [Wood, Tile, Marble, Stone]  ...      USD               5       True
# 5601               [Tile, Carpet]  ...      USD               1       True
#
#       hasHeating  hasFireplace  hasPrivatePool hasSpa  hasView  \
# 17          True           NaN             NaN  False    False
# 36          True           NaN             NaN  False     True
# 38           NaN           NaN             NaN  False    False
# 62          True           NaN             NaN  False    False
# 80          True          True             NaN  False    False
# ...          ...           ...             ...    ...      ...
# 5580        True          True            True   True     True
# 5581       False           NaN             NaN  False    False
# 5591        True          True             NaN  False     True
# 5593        True          True             NaN   True     True
# 5601        True          True             NaN  False     True
#
#                                        securityFeatures Unnamed: 38
# 17                                                  NaN         NaN
# 36                                                  NaN         NaN
# 38                                                  NaN         NaN
# 62                                                  NaN         NaN
# 80                                                  NaN         NaN
# ...                                                 ...         ...
# 5580  ['Gated', '24 Hour Security', 'Gated Community...         NaN
# 5581                                                NaN         NaN
# 5591                                                NaN         NaN
# 5593                                   ['Alarm System']         NaN
# 5601                                                NaN         NaN
#
# [1544 rows x 29 columns]

# %%
import ast
df['sold-history']=df['sold-history'].apply(ast.literal_eval)

# %% [markdown]
# ### Currency

# %% [markdown]
# We dropped it because all of them were USD.

# %%
df["currency"].value_counts()
# Out:
# currency
# USD    5103
# Name: count, dtype: int64

# %%
df.drop(columns=["currency"], inplace=True)

# %% [markdown]
# ### Price

# %%
df["price"].isna().sum()
# Out:
# 0

# %%
df["price"].describe()
# Out:
# count    5.103000e+03
# mean     1.408471e+06
# std      1.669138e+06
# min      1.950000e+03
# 25%      7.245000e+05
# 50%      9.950000e+05
# 75%      1.560000e+06
# max      6.000000e+07
# Name: price, dtype: float64

# %% [markdown]
# ### Price per square foot
#
# We drop it because we can infer it from the price and living area and it also has some missing values.

# %%
df.drop(columns=["pricePerSquareFoot"], inplace=True)

# %% [markdown]
# #### Parking Capacity

# %%
df["parkingCapacity"].isna().sum()
# Out:
# 0

# %%
df["parkingCapacity"].describe()
# Out:
# count    5103.000000
# mean        2.213992
# std         1.993734
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         2.000000
# max        32.000000
# Name: parkingCapacity, dtype: float64

# %% [markdown]
# ### Has ....

# %% [markdown]
# We have some columns that indicate if house has a feature or not. We will convert them to 1 or 0 and fill the rows with null values with mode and if they are too much we drop the column.

# %%
pd.set_option('future.no_silent_downcasting', True)

# %%
df["hasCooling"].isna().sum()
# Out:
# 74

# %%
df["hasCooling"].value_counts()
# Out:
# hasCooling
# True     4062
# False     967
# Name: count, dtype: int64

# %%
df["hasCooling"] = df["hasCooling"].fillna(False)

# %%
df["hasHeating"].isna().sum()
# Out:
# 456

# %%
df["hasHeating"].value_counts()
# Out:
# hasHeating
# True     4485
# False     162
# Name: count, dtype: int64

# %%
df["hasHeating"] = df["hasHeating"].fillna(False)

# %%
df["hasFireplace"].isna().sum()
# Out:
# 738

# %%
df["hasFireplace"].value_counts()
# Out:
# hasFireplace
# True     2831
# False    1534
# Name: count, dtype: int64

# %%
df["hasFireplace"] = df["hasFireplace"].fillna(False)

# %%
df["hasPrivatePool"].isna().sum()
# Out:
# 4555

# %% [markdown]
# In private pools all null values were probably False as we don't have any False values.

# %%
df["hasPrivatePool"].value_counts()
# Out:
# hasPrivatePool
# True    548
# Name: count, dtype: int64

# %%
df["hasPrivatePool"] = df["hasPrivatePool"].fillna(False)

# %%
df["hasSpa"].isna().sum()
# Out:
# 0

# %%
df["hasSpa"].value_counts()
# Out:
# hasSpa
# False    4516
# True      587
# Name: count, dtype: int64

# %%
df["hasView"].isna().sum()
# Out:
# 0

# %%
df["hasView"].value_counts()
# Out:
# hasView
# True     4253
# False     850
# Name: count, dtype: int64

# %%
bool_columns = df.select_dtypes(include=['bool']).columns
df[bool_columns] = df[bool_columns].astype(int)

# %% [markdown]
# ### Security Features
# We drop it as it has too many null values.

# %%
df["securityFeatures"].isna().sum()
# Out:
# 3212

# %%
df.drop(columns=["securityFeatures"], inplace=True)

# %%
df.drop(columns=["Unnamed: 38"], inplace=True)

# %% [markdown]
# Finally We save the preprocessed data in a csv file.

# %%
df.to_csv("preprocessed_data.csv", index=False)
