# %%
import pandas as pd 

df = pd.read_csv("modified_data.csv")

df.head()
# Out:
#    zipcode              streetAddress     homeStatus           homeType  \
# 0    90049  11645 Montana Ave APT 229  RECENTLY_SOLD              CONDO
# 1    90046         2316 Laurelmont Pl  RECENTLY_SOLD  HOME_TYPE_UNKNOWN
# 2    91406        6452 Woodley Ave #3  RECENTLY_SOLD          APARTMENT
# 3    91406    6452 Woodley Ave UNIT 2  RECENTLY_SOLD  HOME_TYPE_UNKNOWN
# 4    90059          855 E 120th St #3  RECENTLY_SOLD          APARTMENT
#
#     latitude   longitude  yearBuilt  lotAreaValue lotAreaUnits  \
# 0  34.056390 -118.465990     1973.0        1.1479        Acres
# 1  34.113050 -118.371925        NaN     1970.0000  Square Feet
# 2  34.188200 -118.483284     2006.0           NaN         sqft
# 3  34.188200 -118.483284        NaN           NaN         sqft
# 4  33.924007 -118.259570        NaN           NaN         sqft
#
#    livingAreaValue  ...             sewer  roofType  taxAssessedValue  \
# 0            855.0  ...  ['Public Sewer']       NaN          699000.0
# 1              NaN  ...               NaN       NaN             437.0
# 2           1800.0  ...               NaN       NaN               NaN
# 3              NaN  ...               NaN       NaN               NaN
# 4            912.0  ...               NaN       NaN               NaN
#
#    zestimate  rentZestimate              sold-history pricePerSquareFoot  \
# 0   701200.0         2999.0  [('2022-08-12', 699000)]                4.0
# 1        NaN         9499.0                        []                NaN
# 2   690500.0         2634.0                        []                2.0
# 3   565500.0         2167.0                        []                NaN
# 4        NaN         3174.0                        []                3.0
#
#   price currency Unnamed: 30
# 0  3050      USD         NaN
# 1  2600      USD         NaN
# 2  3500      USD         NaN
# 3  2500      USD         NaN
# 4  2750      USD         NaN
#
# [5 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5606 entries, 0 to 5605
# Data columns (total 31 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   zipcode                5606 non-null   int64
#  1   streetAddress          5606 non-null   object
#  2   homeStatus             5606 non-null   object
#  3   homeType               5606 non-null   object
#  4   latitude               5602 non-null   float64
#  5   longitude              5602 non-null   float64
#  6   yearBuilt              5391 non-null   float64
#  7   lotAreaValue           5438 non-null   float64
#  8   lotAreaUnits           5606 non-null   object
#  9   livingAreaValue        5439 non-null   float64
#  10  livingAreaUnitsShort   5438 non-null   object
#  11  garageParkingCapacity  3393 non-null   float64
#  12  bedrooms               5429 non-null   float64
#  13  bathrooms              5437 non-null   float64
#  14  bathroomsFull          4640 non-null   float64
#  15  stories                4347 non-null   float64
#  16  flooring               4066 non-null   object
#  17  foundationDetails      5546 non-null   object
#  18  heating                4995 non-null   object
#  19  cooling                5361 non-null   object
#  20  fireplaceFeatures      4408 non-null   object
#  21  sewer                  3189 non-null   object
#  22  roofType               1264 non-null   object
#  23  taxAssessedValue       5040 non-null   float64
#  24  zestimate              5185 non-null   float64
#  25  rentZestimate          5563 non-null   float64
#  26  sold-history           5606 non-null   object
#  27  pricePerSquareFoot     5433 non-null   float64
#  28  price                  5606 non-null   int64
#  29  currency               5606 non-null   object
#  30  Unnamed: 30            0 non-null      float64
# dtypes: float64(15), int64(2), object(14)
# memory usage: 1.3+ MB

# %%
df["homeStatus"].value_counts()
# Out:
# homeStatus
# RECENTLY_SOLD      5434
# FOR_SALE             81
# FOR_RENT             60
# PENDING              16
# PRE_FORECLOSURE      11
# FORECLOSED            2
# OTHER                 2
# Name: count, dtype: int64

# %%
df_not_sold = df[df['homeStatus'] != 'RECENTLY_SOLD']

df = df[df['homeStatus'] == 'RECENTLY_SOLD']

# %%
df_not_sold.head()
# Out:
#      zipcode                streetAddress homeStatus       homeType  \
# 111    90057                216 S Lake St   FOR_SALE  SINGLE_FAMILY
# 161    90020    360 S Kenmore Ave APT 310   FOR_SALE          CONDO
# 179    91342  14075 Foothill Blvd APT 13A   FOR_SALE          CONDO
# 192    91316    5400 Newcastle Ave APT 42   FOR_SALE          CONDO
# 279    91402          8801 Willis Ave #31   FOR_RENT      APARTMENT
#
#       latitude   longitude  yearBuilt  lotAreaValue lotAreaUnits  \
# 111  34.065617 -118.271940     1903.0     6098.4000  Square Feet
# 161  34.067370 -118.296265     1965.0        0.3486        Acres
# 179  34.315300 -118.439770     1977.0        0.4986        Acres
# 192  34.168633 -118.523580     1967.0        1.3996        Acres
# 279  34.230145 -118.455894        NaN           NaN         sqft
#
#      livingAreaValue  ...             sewer  roofType  taxAssessedValue  \
# 111           3323.0  ...               NaN       NaN               NaN
# 161            603.0  ...               NaN       NaN               NaN
# 179            615.0  ...               NaN       NaN               NaN
# 192            648.0  ...  ['Public Sewer']       NaN               NaN
# 279            997.0  ...               NaN       NaN               NaN
#
#      zestimate  rentZestimate  \
# 111    28800.0         9563.0
# 161   379600.0         1999.0
# 179   377000.0         2014.0
# 192   410100.0         1949.0
# 279   355700.0         2631.0
#
#                                           sold-history pricePerSquareFoot  \
# 111                           [('2006-02-06', 709000)]                0.0
# 161  [('2009-12-28', 130500), ('2009-01-07', 115000...              647.0
# 179                           [('2019-09-11', 196000)]              584.0
# 192     [('2001-04-24', 85000), ('1998-07-27', 56000)]              594.0
# 279  [('2015-05-07', 202000), ('2011-04-28', 100000...                3.0
#
#       price currency Unnamed: 30
# 111    1095      USD         NaN
# 161  389900      USD         NaN
# 179  359000      USD         NaN
# 192  385000      USD         NaN
# 279    2700      USD         NaN
#
# [5 rows x 31 columns]

# %%
df_not_sold.to_csv("not_sold.csv", index=False)

# %%
df.drop(columns=['homeStatus'], inplace=True)

# %% [markdown]
# CHECK DUPLICATION

# %%
print("size before duplication removal: ", df.shape)

df.drop_duplicates(inplace=True)

print("size after duplication removal: ", df.shape)
# Out:
# size before duplication removal:  (5434, 30)
# size after duplication removal:  (5434, 30)

# %%
df["homeType"].value_counts()
# Out:
# homeType
# SINGLE_FAMILY        3443
# CONDO                 971
# MULTI_FAMILY          473
# TOWNHOUSE             317
# LOT                   110
# MANUFACTURED           48
# HOME_TYPE_UNKNOWN      37
# APARTMENT              35
# Name: count, dtype: int64

# %%
df[df["homeType"] == "HOME_TYPE_UNKNOWN"].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37 entries, 1 to 5352
# Data columns (total 30 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   zipcode                37 non-null     int64
#  1   streetAddress          37 non-null     object
#  2   homeType               37 non-null     object
#  3   latitude               37 non-null     float64
#  4   longitude              37 non-null     float64
#  5   yearBuilt              3 non-null      float64
#  6   lotAreaValue           27 non-null     float64
#  7   lotAreaUnits           37 non-null     object
#  8   livingAreaValue        3 non-null      float64
#  9   livingAreaUnitsShort   3 non-null      object
#  10  garageParkingCapacity  0 non-null      float64
#  11  bedrooms               1 non-null      float64
#  12  bathrooms              2 non-null      float64
#  13  bathroomsFull          1 non-null      float64
#  14  stories                0 non-null      float64
#  15  flooring               37 non-null     object
#  16  foundationDetails      37 non-null     object
#  17  heating                37 non-null     object
#  18  cooling                37 non-null     object
#  19  fireplaceFeatures      0 non-null      object
#  20  sewer                  0 non-null      object
#  21  roofType               0 non-null      object
#  22  taxAssessedValue       28 non-null     float64
#  23  zestimate              4 non-null      float64
#  24  rentZestimate          34 non-null     float64
#  25  sold-history           37 non-null     object
#  26  pricePerSquareFoot     3 non-null      float64
#  27  price                  37 non-null     int64
#  28  currency               37 non-null     object
#  29  Unnamed: 30            0 non-null      float64
# dtypes: float64(15), int64(2), object(13)
# memory usage: 9.0+ KB

# %%
df = df[df["homeType"] != "HOME_TYPE_UNKNOWN"]

# %%
df[df["latitude"].isnull()]
# Out:
#       zipcode          streetAddress       homeType  latitude  longitude  \
# 3682    91367  (Undisclosed Address)  SINGLE_FAMILY       NaN        NaN
# 4342    90049  (Undisclosed Address)          CONDO       NaN        NaN
# 4929    91423  (Undisclosed Address)  SINGLE_FAMILY       NaN        NaN
# 4961    90025  (Undisclosed Address)   MULTI_FAMILY       NaN        NaN
#
#       yearBuilt  lotAreaValue lotAreaUnits  livingAreaValue  \
# 3682     1959.0        0.2610        Acres           2230.0
# 4342     1994.0        1.9413        Acres           2176.0
# 4929     1940.0        0.3430        Acres           3407.0
# 4961     1964.0     6329.2680  Square Feet           6656.0
#
#      livingAreaUnitsShort  ...                               sewer  \
# 3682                 sqft  ...                       ['In Street']
# 4342                 sqft  ...                                 NaN
# 4929                 sqft  ...  ['In Street', 'Connected on Bond']
# 4961                 sqft  ...                                 NaN
#
#                                 roofType  taxAssessedValue  zestimate  \
# 3682                             Asphalt               NaN  1275600.0
# 4342                                 NaN               NaN  1686000.0
# 4929  Composition,Concrete,Shake,Shingle               NaN  2385400.0
# 4961                                 NaN               NaN  2435500.0
#
#       rentZestimate                                      sold-history  \
# 3682         6675.0  [('2004-06-03', 600000), ('2001-01-03', 380500)]
# 4342         7787.0                                                []
# 4929        15442.0                                                []
# 4961         4393.0                                                []
#
#      pricePerSquareFoot    price currency Unnamed: 30
# 3682              565.0  1259000      USD         NaN
# 4342              758.0  1650000      USD         NaN
# 4929              694.0  2365000      USD         NaN
# 4961              357.0  2375000      USD         NaN
#
# [4 rows x 30 columns]

# %%
df["latitude"].describe()
# Out:
# count    5393.000000
# mean       34.102236
# std         0.120297
# min        33.706684
# 25%        34.038242
# 50%        34.105583
# 75%        34.190070
# max        34.326786
# Name: latitude, dtype: float64

# %%
df["longitude"].describe()
# Out:
# count    5393.000000
# mean     -118.403168
# std         0.115175
# min      -118.667270
# 25%      -118.477260
# 50%      -118.404440
# 75%      -118.307080
# max      -118.159600
# Name: longitude, dtype: float64

# %%
df.drop(columns=['latitude', 'longitude'], inplace=True)

# %%
df["yearBuilt"].describe()
# Out:
# count    5255.000000
# mean     1960.963463
# std        40.234308
# min         0.000000
# 25%      1941.000000
# 50%      1957.000000
# 75%      1980.000000
# max      2024.000000
# Name: yearBuilt, dtype: float64

# %%
df[df["yearBuilt"] < 1900]
# Out:
#       zipcode           streetAddress       homeType  yearBuilt  lotAreaValue  \
# 64      91307        22710 Saticoy St  SINGLE_FAMILY        0.0     8460.0000
# 383     90012  257 S Spring St APT 4L          CONDO     1899.0        0.6616
# 1069    90011           223 E 24th St  SINGLE_FAMILY     1899.0     5249.0000
# 1092    90026          1309 Colton St  SINGLE_FAMILY     1885.0     5571.0000
# 1365    90026        1526 Rockwood St  SINGLE_FAMILY     1885.0     5969.0000
# 1694    90031         300 S Avenue 19   MULTI_FAMILY     1895.0     7500.0000
# 1964    90031        2621 Johnston St  SINGLE_FAMILY     1895.0        0.2702
# 3075    90006           1116 Irolo St  SINGLE_FAMILY     1896.0     5906.7360
# 3435    90033       2014 Michigan Ave   MULTI_FAMILY     1890.0     7413.9120
# 3607    90026       2128 Reservoir St  SINGLE_FAMILY     1895.0     7744.9680
# 4051    90007          1033 W 30th St  SINGLE_FAMILY     1890.0     6842.0000
#
#      lotAreaUnits  livingAreaValue livingAreaUnitsShort  \
# 64          Acres           1372.0                 sqft
# 383         Acres            650.0                 sqft
# 1069  Square Feet           1205.0                 sqft
# 1092  Square Feet            852.0                 sqft
# 1365  Square Feet            880.0                 sqft
# 1694  Square Feet           1952.0                 sqft
# 1964        Acres           1800.0                 sqft
# 3075  Square Feet           1718.0                 sqft
# 3435  Square Feet           2952.0                 sqft
# 3607  Square Feet           1770.0                 sqft
# 4051  Square Feet           1655.0                 sqft
#
#       garageParkingCapacity  bedrooms  ...                            sewer  \
# 64                      NaN       4.0  ...                              NaN
# 383                     1.0       0.0  ...                              NaN
# 1069                    0.0       2.0  ...                 ['Public Sewer']
# 1092                    NaN       2.0  ...                              NaN
# 1365                    0.0       1.0  ...                 ['Public Sewer']
# 1694                    0.0       2.0  ...                 ['Public Sewer']
# 1964                    NaN       3.0  ...                              NaN
# 3075                    NaN       3.0  ...  ['In Street', 'In Street Paid']
# 3435                    NaN       7.0  ...                              NaN
# 3607                    NaN       4.0  ...                    ['In Street']
# 4051                    1.0       3.0  ...                 ['Public Sewer']
#
#                       roofType  taxAssessedValue  zestimate rentZestimate  \
# 64                         NaN          652800.0  1284200.0        4057.0
# 383                        NaN          121000.0   417400.0        2314.0
# 1069                       NaN           56761.0   627200.0        3200.0
# 1092                       NaN          361201.0   632600.0        2890.0
# 1365                       NaN          106133.0   711600.0        2997.0
# 1694                       NaN          469744.0   761700.0        4914.0
# 1964                       NaN          225016.0   806000.0        4407.0
# 3075       Composition,Shingle         1217268.0        NaN        4300.0
# 3435                       NaN         1102684.0  1212500.0        3347.0
# 3607  Composition,Flat,Shingle           58903.0        NaN        6995.0
# 4051                       NaN          369418.0        NaN        3914.0
#
#                                            sold-history pricePerSquareFoot  \
# 64    [('2023-11-28', 1230000), ('2021-12-16', 640000)]                3.0
# 383        [('2016-11-30', 2000), ('2016-08-19', 2150)]              631.0
# 1069                                                 []              519.0
# 1092  [('2005-10-25', 275000), ('2004-05-27', 270000...              734.0
# 1365                                                 []              790.0
# 1694                           [('2004-03-30', 320000)]              384.0
# 1964                                                 []              444.0
# 3075  [('2020-10-26', 1170000), ('2019-09-27', 765000)]              620.0
# 3435  [('2020-03-06', 1049000), ('2013-03-14', 40000...              403.0
# 3607                                                 []              706.0
# 4051                                                 []              876.0
#
#         price currency Unnamed: 30
# 64       3900      USD         NaN
# 383    410000      USD         NaN
# 1069   625000      USD         NaN
# 1092   625000      USD         NaN
# 1365   695000      USD         NaN
# 1694   750000      USD         NaN
# 1964   800000      USD         NaN
# 3075  1065000      USD         NaN
# 3435  1190000      USD         NaN
# 3607  1250000      USD         NaN
# 4051  1450000      USD         NaN
#
# [11 rows x 28 columns]

# %%
df = df[df["yearBuilt"] > 0]

# %%
df["yearBuilt"] = df["yearBuilt"].astype(int)

# %%
df["yearBuilt"]
# Out:
# 0       1973
# 2       2006
# 5       1961
# 6       1981
# 8       1945
#         ...
# 5601    1952
# 5602    2023
# 5603    2021
# 5604    2023
# 5605    1938
# Name: yearBuilt, Length: 5254, dtype: int32

# %%
df["lotAreaUnits"].unique()
# Out:
# array(['Acres', 'sqft', 'Square Feet'], dtype=object)

# %%
df["lotAreaUnits"].replace("Square Feet", 'sqft', inplace=True)
# Out:
# C:\Users\minas\AppData\Local\Temp\ipykernel_2244\1543183995.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["lotAreaUnits"].replace("Square Feet", 'sqft', inplace=True)

# %%
import pandas as pd

conversion_factors = {
    'sqft': 0.092903,
    'Acres': 4046.86,
}

# Convert all areas to square meters
df['lotAreaValue'] = df.apply(
    lambda row: row['lotAreaValue'] * conversion_factors[row['lotAreaUnits']],
    axis=1
)

# %%
df["livingAreaUnitsShort"].unique()
# Out:
# array(['sqft', nan], dtype=object)

# %%
df["livingAreaUnitsShort"].fillna("sqft", inplace=True)
# Out:
# C:\Users\minas\AppData\Local\Temp\ipykernel_2244\3391398173.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["livingAreaUnitsShort"].fillna("sqft", inplace=True)

# %%
df["livingAreaUnitsShort"].unique()
# Out:
# array(['sqft'], dtype=object)

# %%
df['livingAreaValue'] = df.apply(
    lambda row: row['livingAreaValue'] * conversion_factors[row['livingAreaUnitsShort']],
    axis=1
)

# %%
df.head()
# Out:
#    zipcode                 streetAddress       homeType  yearBuilt  \
# 0    90049     11645 Montana Ave APT 229          CONDO       1973
# 2    91406           6452 Woodley Ave #3      APARTMENT       2006
# 5    90066  4040 Grand View Blvd UNIT 15      TOWNHOUSE       1961
# 6    91303        7305 Milwood Ave APT 3          CONDO       1981
# 8    91040              8701 Hillrose St  SINGLE_FAMILY       1945
#
#    lotAreaValue lotAreaUnits  livingAreaValue livingAreaUnitsShort  \
# 0   4645.390594        Acres        79.432065                 sqft
# 2           NaN         sqft       167.225400                 sqft
# 5  11561.886452        Acres        78.131423                 sqft
# 6     80.918513         sqft        90.301716                 sqft
# 8   7098.170143        Acres       129.320976                 sqft
#
#    garageParkingCapacity  bedrooms  ...             sewer  roofType  \
# 0                    2.0       1.0  ...  ['Public Sewer']       NaN
# 2                    NaN       3.0  ...               NaN       NaN
# 5                    NaN       2.0  ...               NaN     Other
# 6                    NaN       2.0  ...               NaN       NaN
# 8                    NaN       2.0  ...               NaN       NaN
#
#    taxAssessedValue zestimate rentZestimate  \
# 0          699000.0  701200.0        2999.0
# 2               NaN  690500.0        2634.0
# 5          512017.0  734100.0        3997.0
# 6          105445.0  464800.0        3499.0
# 8           68036.0  759600.0        3781.0
#
#                                         sold-history pricePerSquareFoot price  \
# 0                           [('2022-08-12', 699000)]                4.0  3050
# 2                                                 []                2.0  3500
# 5   [('2015-10-21', 450000), ('2005-04-07', 396000)]                4.0  3100
# 6  [('2009-11-13', 85000), ('2007-04-18', 299000)...                3.0  2800
# 8       [('2021-06-29', 3350), ('2019-01-22', 3150)]                3.0  3600
#
#   currency Unnamed: 30
# 0      USD         NaN
# 2      USD         NaN
# 5      USD         NaN
# 6      USD         NaN
# 8      USD         NaN
#
# [5 rows x 28 columns]

# %%
df["lotAreaValue"].describe()
# Out:
# count    5.176000e+03
# mean     3.507705e+05
# std      2.288397e+07
# min      0.000000e+00
# 25%      5.529888e+02
# 50%      6.990486e+02
# 75%      1.554737e+03
# max      1.644773e+09
# Name: lotAreaValue, dtype: float64

# %%
df[(df["lotAreaValue"] < df["livingAreaValue"]) & (df["lotAreaValue"] > 0.1)]
# Out:
#       zipcode           streetAddress       homeType  yearBuilt  lotAreaValue  \
# 6       91303  7305 Milwood Ave APT 3          CONDO       1981     80.918513
# 85      91601   5706 Fair Ave APT 200          CONDO       1981     81.754640
# 1186    90037     1006 W Leighton Ave      TOWNHOUSE       2008    112.133921
# 1345    90011       4146 Woodlawn Ave   MULTI_FAMILY       1906    359.070095
# 1547    91405        14104 W Birch Ln  SINGLE_FAMILY       2016    101.171367
# ...       ...                     ...            ...        ...           ...
# 5556    90272       756 Via De La Paz  SINGLE_FAMILY       2016    696.868376
# 5570    91303        21121 Vanowen St  SINGLE_FAMILY       2021   2623.491266
# 5581    90004        4804 Oakwood Ave      APARTMENT       2022   1347.095271
# 5597    90021          1001 Towne Ave  SINGLE_FAMILY       2005   2300.745820
# 5598    90021           777 E 10th St  SINGLE_FAMILY       2009   2432.110834
#
#      lotAreaUnits  livingAreaValue livingAreaUnitsShort  \
# 6            sqft        90.301716                 sqft
# 85           sqft        83.612700                 sqft
# 1186         sqft       137.403537                 sqft
# 1345         sqft       401.340960                 sqft
# 1547         sqft       137.310634                 sqft
# ...           ...              ...                  ...
# 5556         sqft       718.790511                 sqft
# 5570        Acres      8004.986995                 sqft
# 5581        Acres      2709.608898                 sqft
# 5597        Acres      4059.954003                 sqft
# 5598        Acres      8584.330103                 sqft
#
#       garageParkingCapacity  bedrooms  ...             sewer  roofType  \
# 6                       NaN       2.0  ...               NaN       NaN
# 85                      NaN       2.0  ...               NaN     Other
# 1186                    2.0       3.0  ...  ['Public Sewer']       NaN
# 1345                    0.0       6.0  ...  ['Public Sewer']       NaN
# 1547                    2.0       3.0  ...               NaN       NaN
# ...                     ...       ...  ...               ...       ...
# 5556                    NaN       4.0  ...               NaN       NaN
# 5570                    NaN       NaN  ...               NaN       NaN
# 5581                    NaN       6.0  ...               NaN       NaN
# 5597                    NaN       NaN  ...               NaN       NaN
# 5598                    NaN       NaN  ...               NaN       NaN
#
#       taxAssessedValue   zestimate rentZestimate  \
# 6             105445.0    464800.0        3499.0
# 85            443210.0    453800.0        2800.0
# 1186          554540.0    662200.0        3635.0
# 1345          840637.0         NaN        3103.0
# 1547          572219.0    729900.0        3532.0
# ...                ...         ...           ...
# 5556         7230779.0   8680600.0       31990.0
# 5570        16930290.0  18943100.0       78262.0
# 5581         9012458.0         NaN       48858.0
# 5597        14280000.0   9386600.0       35200.0
# 5598        29281938.0  11208700.0       42077.0
#
#                                            sold-history pricePerSquareFoot  \
# 6     [('2009-11-13', 85000), ('2007-04-18', 299000)...                3.0
# 85    [('2020-10-26', 426000), ('2005-12-20', 345000...               61.0
# 1186   [('2019-04-30', 517500), ('2011-04-07', 320000)]              439.0
# 1345  [('2023-02-03', 1085015), ('2005-07-21', 64000...              160.0
# 1547   [('2020-09-25', 550000), ('2016-11-30', 432000)]              491.0
# ...                                                 ...                ...
# 5556  [('2020-07-08', 6950000), ('2015-04-09', 26000...             1111.0
# 5570                           [('2015-09-15', 720000)]              650.0
# 5581                                                 []              461.0
# 5597                         [('2021-08-13', 12147694)]              308.0
# 5598                         [('2022-02-18', 28000000)]              195.0
#
#          price currency Unnamed: 30
# 6         2800      USD         NaN
# 85       55000      USD         NaN
# 1186    650000      USD         NaN
# 1345    693000      USD         NaN
# 1547    725000      USD         NaN
# ...        ...      ...         ...
# 5556   8595000      USD         NaN
# 5570  55990500      USD         NaN
# 5581  13450000      USD         NaN
# 5597  13450000      USD         NaN
# 5598  18000000      USD         NaN
#
# [115 rows x 28 columns]

# %%
df[(df["livingAreaValue"] < 1)]
# Out:
#       zipcode             streetAddress       homeType  yearBuilt  \
# 439     90011       1626-1628 E 32nd St   MULTI_FAMILY       1905
# 1955    91402           9146 Willis Ave  SINGLE_FAMILY       1976
# 3762    90016          2923 S Orange Dr   MULTI_FAMILY       1922
# 4495    90029           909 Sanborn Ave  SINGLE_FAMILY       1922
# 4587    90026        1321 Edgecliffe Dr  SINGLE_FAMILY       2023
# 4656    90026        1323 Edgecliffe Dr  SINGLE_FAMILY       2023
# 4687    90037             211 W 43rd St   MULTI_FAMILY       2021
# 5346    90210          9625 Oak Pass Rd  SINGLE_FAMILY       1974
# 5552    90210  2859 Coldwater Canyon Dr  SINGLE_FAMILY       1959
# 5562    91436   15824 Valley Vista Blvd  SINGLE_FAMILY       2024
#
#       lotAreaValue lotAreaUnits  livingAreaValue livingAreaUnitsShort  \
# 439     464.886612         sqft         0.092903                 sqft
# 1955   1618.744000        Acres         0.185806                 sqft
# 3762    669.644824         sqft         0.278709                 sqft
# 4495    497.358440         sqft         0.000000                 sqft
# 4587    682.704385         sqft         0.000000                 sqft
# 4656    682.704385         sqft         0.000000                 sqft
# 4687    589.934050         sqft         0.185806                 sqft
# 5346   1855.080624        Acres         0.000000                 sqft
# 5552  12009.866422        Acres         0.000000                 sqft
# 5562   1442.300904        Acres         0.000000                 sqft
#
#       garageParkingCapacity  bedrooms  ...             sewer  \
# 439                     1.0       4.0  ...  ['Public Sewer']
# 1955                    NaN       4.0  ...               NaN
# 3762                    3.0       5.0  ...  ['Public Sewer']
# 4495                    0.0       2.0  ...     ['In Street']
# 4587                    NaN       4.0  ...               NaN
# 4656                    NaN       4.0  ...               NaN
# 4687                    1.0      15.0  ...  ['Public Sewer']
# 5346                    NaN       4.0  ...     ['In Street']
# 5552                    NaN       7.0  ...               NaN
# 5562                    NaN       5.0  ...               NaN
#
#                   roofType  taxAssessedValue  zestimate rentZestimate  \
# 439                    NaN               NaN   450300.0        1400.0
# 1955                   NaN          536165.0   809700.0        1398.0
# 3762  Asphalt,Shingle,Tile          225434.0  1341300.0        1675.0
# 4495   Composition,Shingle          655945.0  1747500.0        5435.0
# 4587                   NaN         1673585.0  1929800.0        7482.0
# 4656                   NaN               NaN  1978600.0        7479.0
# 4687                   NaN         1887000.0  2059000.0        1407.0
# 5346                   NaN         2626673.0  3665000.0       10997.0
# 5552                   NaN        11424000.0        NaN       30399.0
# 5562                   NaN         2907000.0  8004500.0       14596.0
#
#                                            sold-history pricePerSquareFoot  \
# 439                                                  []           440000.0
# 1955  [('2009-05-22', 299500), ('2008-04-16', 540000...           400000.0
# 3762   [('1996-06-12', 141000), ('1996-01-11', 118733)]           433333.0
# 4495  [('2023-07-28', 1600000), ('2003-09-09', 48000...                NaN
# 4587                           [('2015-07-10', 650000)]                NaN
# 4656                                                 []                NaN
# 4687  [('2022-02-14', 1850000), ('2020-05-22', 479000)]          1000000.0
# 5346  [('2018-08-09', 9000), ('2015-12-08', 1900000)...                NaN
# 5552  [('2022-01-31', 11200000), ('2016-01-15', 1221...                NaN
# 5562  [('2022-06-30', 2850000), ('1996-09-13', 830000)]                NaN
#
#         price currency Unnamed: 30
# 439    440000      USD         NaN
# 1955   800000      USD         NaN
# 3762  1300000      USD         NaN
# 4495  1729000      USD         NaN
# 4587  1850000      USD         NaN
# 4656  1930000      USD         NaN
# 4687  2000000      USD         NaN
# 5346  3607500      USD         NaN
# 5552  7800000      USD         NaN
# 5562  8000000      USD         NaN
#
# [10 rows x 28 columns]

# %%
df.loc[df['livingAreaValue'] > df['lotAreaValue'], 'lotAreaValue'] = df['livingAreaValue']

# %%
df[df["lotAreaValue"] < 1]
# Out:
# Empty DataFrame
# Columns: [zipcode, streetAddress, homeType, yearBuilt, lotAreaValue, lotAreaUnits, livingAreaValue, livingAreaUnitsShort, garageParkingCapacity, bedrooms, bathrooms, bathroomsFull, stories, flooring, foundationDetails, heating, cooling, fireplaceFeatures, sewer, roofType, taxAssessedValue, zestimate, rentZestimate, sold-history, pricePerSquareFoot, price, currency, Unnamed: 30]
# Index: []
#
# [0 rows x 28 columns]

# %%
df[(df["livingAreaValue"] < 1)]
# Out:
#       zipcode             streetAddress       homeType  yearBuilt  \
# 439     90011       1626-1628 E 32nd St   MULTI_FAMILY       1905
# 1955    91402           9146 Willis Ave  SINGLE_FAMILY       1976
# 3762    90016          2923 S Orange Dr   MULTI_FAMILY       1922
# 4495    90029           909 Sanborn Ave  SINGLE_FAMILY       1922
# 4587    90026        1321 Edgecliffe Dr  SINGLE_FAMILY       2023
# 4656    90026        1323 Edgecliffe Dr  SINGLE_FAMILY       2023
# 4687    90037             211 W 43rd St   MULTI_FAMILY       2021
# 5346    90210          9625 Oak Pass Rd  SINGLE_FAMILY       1974
# 5552    90210  2859 Coldwater Canyon Dr  SINGLE_FAMILY       1959
# 5562    91436   15824 Valley Vista Blvd  SINGLE_FAMILY       2024
#
#       lotAreaValue lotAreaUnits  livingAreaValue livingAreaUnitsShort  \
# 439     464.886612         sqft         0.092903                 sqft
# 1955   1618.744000        Acres         0.185806                 sqft
# 3762    669.644824         sqft         0.278709                 sqft
# 4495    497.358440         sqft         0.000000                 sqft
# 4587    682.704385         sqft         0.000000                 sqft
# 4656    682.704385         sqft         0.000000                 sqft
# 4687    589.934050         sqft         0.185806                 sqft
# 5346   1855.080624        Acres         0.000000                 sqft
# 5552  12009.866422        Acres         0.000000                 sqft
# 5562   1442.300904        Acres         0.000000                 sqft
#
#       garageParkingCapacity  bedrooms  ...             sewer  \
# 439                     1.0       4.0  ...  ['Public Sewer']
# 1955                    NaN       4.0  ...               NaN
# 3762                    3.0       5.0  ...  ['Public Sewer']
# 4495                    0.0       2.0  ...     ['In Street']
# 4587                    NaN       4.0  ...               NaN
# 4656                    NaN       4.0  ...               NaN
# 4687                    1.0      15.0  ...  ['Public Sewer']
# 5346                    NaN       4.0  ...     ['In Street']
# 5552                    NaN       7.0  ...               NaN
# 5562                    NaN       5.0  ...               NaN
#
#                   roofType  taxAssessedValue  zestimate rentZestimate  \
# 439                    NaN               NaN   450300.0        1400.0
# 1955                   NaN          536165.0   809700.0        1398.0
# 3762  Asphalt,Shingle,Tile          225434.0  1341300.0        1675.0
# 4495   Composition,Shingle          655945.0  1747500.0        5435.0
# 4587                   NaN         1673585.0  1929800.0        7482.0
# 4656                   NaN               NaN  1978600.0        7479.0
# 4687                   NaN         1887000.0  2059000.0        1407.0
# 5346                   NaN         2626673.0  3665000.0       10997.0
# 5552                   NaN        11424000.0        NaN       30399.0
# 5562                   NaN         2907000.0  8004500.0       14596.0
#
#                                            sold-history pricePerSquareFoot  \
# 439                                                  []           440000.0
# 1955  [('2009-05-22', 299500), ('2008-04-16', 540000...           400000.0
# 3762   [('1996-06-12', 141000), ('1996-01-11', 118733)]           433333.0
# 4495  [('2023-07-28', 1600000), ('2003-09-09', 48000...                NaN
# 4587                           [('2015-07-10', 650000)]                NaN
# 4656                                                 []                NaN
# 4687  [('2022-02-14', 1850000), ('2020-05-22', 479000)]          1000000.0
# 5346  [('2018-08-09', 9000), ('2015-12-08', 1900000)...                NaN
# 5552  [('2022-01-31', 11200000), ('2016-01-15', 1221...                NaN
# 5562  [('2022-06-30', 2850000), ('1996-09-13', 830000)]                NaN
#
#         price currency Unnamed: 30
# 439    440000      USD         NaN
# 1955   800000      USD         NaN
# 3762  1300000      USD         NaN
# 4495  1729000      USD         NaN
# 4587  1850000      USD         NaN
# 4656  1930000      USD         NaN
# 4687  2000000      USD         NaN
# 5346  3607500      USD         NaN
# 5552  7800000      USD         NaN
# 5562  8000000      USD         NaN
#
# [10 rows x 28 columns]

# %%
df.loc[df['livingAreaValue'] < 1, 'livingAreaValue'] = df['lotAreaValue']

# %%
df["garageParkingCapacity"].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 5254 entries, 0 to 5605
# Series name: garageParkingCapacity
# Non-Null Count  Dtype
# --------------  -----
# 3308 non-null   float64
# dtypes: float64(1)
# memory usage: 211.1 KB

# %%
df["garageParkingCapacity"].describe()
# Out:
# count    3308.000000
# mean        1.707074
# std         1.100232
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         2.000000
# max        21.000000
# Name: garageParkingCapacity, dtype: float64

# %%
df[df["garageParkingCapacity"]==0]
# Out:
#       zipcode               streetAddress       homeType  yearBuilt  \
# 123     91304      24303 Woolsey Cyn #121   MANUFACTURED       1979
# 124     91342  12301 San Fernando Rd #809   MANUFACTURED       2016
# 125     91342       13120 Bradley Ave #30   MANUFACTURED       1978
# 133     91311   21001 Plummer St SPACE 71   MANUFACTURED       1969
# 141     91605        8250 Lankershim Blvd   MANUFACTURED       1990
# ...       ...                         ...            ...        ...
# 5350    90028         1406 N Sycamore Ave   MULTI_FAMILY       2024
# 5372    91364            4701 Almidor Ave  SINGLE_FAMILY       1928
# 5381    90037           1260 Leighton Ave   MULTI_FAMILY       2023
# 5425    90024          10633 Le Conte Ave  SINGLE_FAMILY       1928
# 5504    90033            571 Fairview Ave   MULTI_FAMILY       1964
#
#       lotAreaValue lotAreaUnits  livingAreaValue livingAreaUnitsShort  \
# 123            NaN         sqft       164.995728                 sqft
# 124            NaN         sqft        40.134096                 sqft
# 125            NaN         sqft        65.403712                 sqft
# 133            NaN         sqft        60.201144                 sqft
# 141     111.483600         sqft        69.677250                 sqft
# ...            ...          ...              ...                  ...
# 5350    597.180484         sqft       597.180484                 sqft
# 5372   3815.379608        Acres       492.385900                 sqft
# 5381    730.589192         sqft       730.589192                 sqft
# 5425    756.137517         sqft       302.306362                 sqft
# 5504   1568.111798        Acres      1115.393418                 sqft
#
#       garageParkingCapacity  bedrooms  ...             sewer     roofType  \
# 123                     0.0       3.0  ...               NaN          NaN
# 124                     0.0       2.0  ...  ['Public Sewer']          NaN
# 125                     0.0       2.0  ...  ['Public Sewer']  Composition
# 133                     0.0       2.0  ...  ['Public Sewer']         Flat
# 141                     0.0       2.0  ...  ['Public Sewer']          NaN
# ...                     ...       ...  ...               ...          ...
# 5350                    0.0      15.0  ...  ['Public Sewer']          NaN
# 5372                    0.0       4.0  ...               NaN    Flat,Tile
# 5381                    0.0      16.0  ...  ['Public Sewer']          NaN
# 5425                    0.0       4.0  ...  ['Public Sewer']          NaN
# 5504                    0.0       1.0  ...  ['Public Sewer']          NaN
#
#       taxAssessedValue  zestimate rentZestimate  \
# 123                NaN   146800.0         624.0
# 124                NaN    96600.0         367.0
# 125                NaN   145700.0         553.0
# 133                NaN   122400.0         496.0
# 141            17860.0   135600.0         505.0
# ...                ...        ...           ...
# 5350         1377000.0  3734800.0       14438.0
# 5372         1350317.0  3673000.0       14297.0
# 5381          669599.0  3831700.0       14730.0
# 5425         3017888.0  4070900.0       15670.0
# 5504               NaN  5088500.0       19450.0
#
#                                            sold-history pricePerSquareFoot  \
# 123                                                  []               82.0
# 124                                                  []              220.0
# 125                                                  []              203.0
# 133                                                  []              188.0
# 141                                                  []              180.0
# ...                                                 ...                ...
# 5350  [('2021-11-01', 1350000), ('1997-04-16', 180000)]              575.0
# 5372                           [('2002-08-21', 485000)]              736.0
# 5381                           [('2019-10-18', 637000)]              477.0
# 5425      [('2020-07-31', 88223), ('1998-07-30', 5800)]             1229.0
# 5504                                                 []              416.0
#
#         price currency Unnamed: 30
# 123    145000      USD         NaN
# 124     95000      USD         NaN
# 125    143000      USD         NaN
# 133    122000      USD         NaN
# 141    135000      USD         NaN
# ...       ...      ...         ...
# 5350  3699000      USD         NaN
# 5372  3900000      USD         NaN
# 5381  3750000      USD         NaN
# 5425  4000000      USD         NaN
# 5504  4995000      USD         NaN
#
# [518 rows x 28 columns]

# %%
df["bedrooms"].value_counts()
# Out:
# bedrooms
# 3.0     1855
# 2.0     1229
# 4.0     1074
# 5.0      417
# 1.0      278
# 6.0      131
# 8.0       67
# 7.0       46
# 12.0      19
# 0.0       19
# 9.0       17
# 10.0      14
# 16.0      10
# 13.0       9
# 11.0       6
# 14.0       4
# 18.0       4
# 17.0       2
# 36.0       2
# 15.0       2
# 20.0       2
# 40.0       1
# 34.0       1
# 24.0       1
# 19.0       1
# 25.0       1
# 35.0       1
# 33.0       1
# 28.0       1
# 99.0       1
# 44.0       1
# 72.0       1
# 32.0       1
# 31.0       1
# Name: count, dtype: int64

# %%
df[df["bedrooms"] > 30].sort_values(by="bedrooms")
# Out:
#       zipcode             streetAddress       homeType  yearBuilt  \
# 5521    90034            10915 Rose Ave   MULTI_FAMILY       1971
# 510     90026             211 N Reno St      APARTMENT       1925
# 5280    91605          13135 Vanowen St   MULTI_FAMILY       1960
# 5378    90016    5110 W Washington Blvd   MULTI_FAMILY       1946
# 3634    90039        2938 Allesandro St  SINGLE_FAMILY       2022
# 5446    90006            1029 Elden Ave   MULTI_FAMILY       1991
# 5466    90003  5869-5875 S San Pedro St   MULTI_FAMILY       2023
# 5299    90044             649 W 92nd St   MULTI_FAMILY       2023
# 3699    90065      3516 Arroyo Seco Ave   MULTI_FAMILY       1964
# 3216    90011             637 E 23rd St   MULTI_FAMILY       1957
# 4329    91401           14106 Delano St   MULTI_FAMILY       1963
#
#       lotAreaValue lotAreaUnits  livingAreaValue livingAreaUnitsShort  \
# 5521   1899.866350         sqft      1899.866350                 sqft
# 510    1065.691714        Acres       992.204040                 sqft
# 5280   1547.923950        Acres      1399.769501                 sqft
# 5378   2207.157444        Acres      1011.249155                 sqft
# 3634   3015.259768        Acres      3015.259768                 sqft
# 5446   2024.263467        Acres      2024.263467                 sqft
# 5466   1667.330141        Acres      1667.330141                 sqft
# 5299   1765.240332        Acres      1196.590640                 sqft
# 3699    761.154279         sqft       435.343458                 sqft
# 3216    541.067072         sqft       327.018560                 sqft
# 4329    694.728634         sqft       513.567784                 sqft
#
#       garageParkingCapacity  bedrooms  ...                           sewer  \
# 5521                    NaN      31.0  ...                             NaN
# 510                     NaN      32.0  ...                             NaN
# 5280                    NaN      33.0  ...                             NaN
# 5378                    NaN      34.0  ...                             NaN
# 3634                    NaN      35.0  ...                             NaN
# 5446                    NaN      36.0  ...                             NaN
# 5466                    8.0      36.0  ...                             NaN
# 5299                    NaN      40.0  ...                             NaN
# 3699                    2.0      44.0  ...                ['Public Sewer']
# 3216                    0.0      72.0  ...                ['Public Sewer']
# 4329                    9.0      99.0  ...  ['Public Sewer', 'Sewer Paid']
#
#                       roofType  taxAssessedValue  zestimate rentZestimate  \
# 5521                       NaN               NaN  4982000.0        9254.0
# 510                        NaN          269670.0        NaN        3998.0
# 5280                       NaN               NaN  3322900.0        3998.0
# 5378                       NaN               NaN  3835700.0       14800.0
# 3634                       NaN          583110.0  2261600.0       13598.0
# 5446                       NaN               NaN  4727900.0       17865.0
# 5466                       NaN               NaN  4909600.0       18748.0
# 5299                       NaN           33084.0        NaN        4146.0
# 3699                       NaN          208241.0  1300600.0        3338.0
# 3216                       NaN               NaN  1137300.0        2531.0
# 4329  Composition,Flat,Shingle               NaN  1605900.0        4467.0
#
#                                         sold-history pricePerSquareFoot  \
# 5521                                              []              243.0
# 510                         [('2021-03-22', 370000)]               44.0
# 5280                                              []              217.0
# 5378                                              []              345.0
# 3634                                              []               39.0
# 5446                                              []              211.0
# 5466                                              []              267.0
# 5299  [('2018-01-02', 630000), ('1986-10-29', 5500)]              267.0
# 3699                                              []              277.0
# 3216                                              []              313.0
# 4329                                              []              289.0
#
#         price currency Unnamed: 30
# 5521  4975000      USD         NaN
# 510    465000      USD         NaN
# 5280  3264000      USD         NaN
# 5378  3750000      USD         NaN
# 3634  1250000      USD         NaN
# 5446  4600000      USD         NaN
# 5466  4800000      USD         NaN
# 5299  3445000      USD         NaN
# 3699  1299998      USD         NaN
# 3216  1100000      USD         NaN
# 4329  1600000      USD         NaN
#
# [11 rows x 28 columns]

# %%
df.drop(index=[4329,510,3634]	, inplace=True)

# %%
df.drop(index=[3699]	, inplace=True)

# %%
df["bedrooms"].value_counts()
# Out:
# bedrooms
# 3.0     1855
# 2.0     1229
# 4.0     1074
# 5.0      417
# 1.0      278
# 6.0      131
# 8.0       67
# 7.0       46
# 12.0      19
# 0.0       19
# 9.0       17
# 10.0      14
# 16.0      10
# 13.0       9
# 11.0       6
# 18.0       4
# 14.0       4
# 36.0       2
# 20.0       2
# 17.0       2
# 15.0       2
# 28.0       1
# 33.0       1
# 40.0       1
# 25.0       1
# 19.0       1
# 24.0       1
# 34.0       1
# 72.0       1
# 31.0       1
# Name: count, dtype: int64

# %%
df["bedrooms"].isna().sum()
# Out:
# 34

# %%
df[df["bedrooms"] == 0].head()
# Out:
#      zipcode                  streetAddress       homeType  yearBuilt  \
# 136    90015                 1421 Albany St  SINGLE_FAMILY       1903
# 238    91316    5325 Newcastle Ave UNIT 128          CONDO       1971
# 315    90012          800 W 1st St APT 1604          CONDO       1968
# 341    90015           645 W 9th St APT 405          CONDO       2006
# 360    90031  200 N San Fernando Rd APT 211          CONDO       1925
#
#      lotAreaValue lotAreaUnits  livingAreaValue livingAreaUnitsShort  \
# 136    558.439933         sqft       190.544053                 sqft
# 238   9585.392596        Acres        44.872149                 sqft
# 315   9874.338400        Acres        44.686343                 sqft
# 341   6943.602388        Acres        61.315980                 sqft
# 360   5868.351686        Acres        62.245010                 sqft
#
#      garageParkingCapacity  bedrooms  ...                sewer     roofType  \
# 136                    NaN       0.0  ...                  NaN          NaN
# 238                    1.0       0.0  ...     ['Public Sewer']          NaN
# 315                    1.0       0.0  ...  ['Sewer Connected']  Composition
# 341                    1.0       0.0  ...     ['Public Sewer']  Common Roof
# 360                    1.0       0.0  ...        ['In Street']          NaN
#
#      taxAssessedValue zestimate rentZestimate  \
# 136          551843.0  700600.0        1614.0
# 238          273409.0  306000.0        1702.0
# 315          131776.0  371600.0        2238.0
# 341          369713.0  405900.0        2441.0
# 360          285719.0  400700.0        2350.0
#
#                                          sold-history pricePerSquareFoot  \
# 136                          [('2015-11-23', 485000)]               32.0
# 238  [('2019-06-25', 255000), ('2006-01-24', 199000)]              621.0
# 315    [('2018-08-31', 21000), ('2000-01-20', 91000)]              759.0
# 341                          [('2010-02-01', 298000)]              606.0
# 360  [('2014-05-16', 242500), ('2013-06-19', 199000)]              596.0
#
#       price currency Unnamed: 30
# 136   66500      USD         NaN
# 238  300000      USD         NaN
# 315  365000      USD         NaN
# 341  400000      USD         NaN
# 360  399000      USD         NaN
#
# [5 rows x 28 columns]

# %%
df[df["bedrooms"].isna()].head()
# Out:
#      zipcode               streetAddress      homeType  yearBuilt  \
# 280    90018              1853 W 25th St  MULTI_FAMILY       1913
# 299    90062              1514 W 55th St  MULTI_FAMILY       1911
# 347    90046   1735 N Fuller Ave APT 422         CONDO       1974
# 354    90017  889 Francisco St UNIT 1807         CONDO       2017
# 540    90044            952 954 Gage Ave  MULTI_FAMILY       1921
#
#      lotAreaValue lotAreaUnits  livingAreaValue livingAreaUnitsShort  \
# 280    617.990756         sqft       280.938672                 sqft
# 299    460.798880         sqft       179.209887                 sqft
# 347   8029.059427        Acres        47.659239                 sqft
# 354   9189.140713        Acres        44.593440                 sqft
# 540    304.536034         sqft        93.646224                 sqft
#
#      garageParkingCapacity  bedrooms  ...             sewer  roofType  \
# 280                    NaN       NaN  ...               NaN       NaN
# 299                    2.0       NaN  ...  ['Public Sewer']       NaN
# 347                    NaN       NaN  ...               NaN       NaN
# 354                    NaN       NaN  ...               NaN       NaN
# 540                    1.0       NaN  ...       ['Unknown']   Shingle
#
#      taxAssessedValue zestimate rentZestimate  \
# 280          314799.0  773800.0        2840.0
# 299          618109.0  688100.0        4603.0
# 347          102824.0  396100.0        1530.0
# 354          494700.0  389800.0        1479.0
# 540               NaN  492000.0        2031.0
#
#                                           sold-history pricePerSquareFoot  \
# 280                           [('1994-07-29', 195000)]              104.0
# 299  [('2023-06-21', 110000), ('2006-08-01', 480000...              194.0
# 347                                                 []              760.0
# 354   [('2022-06-10', 485000), ('2017-03-31', 719500)]              792.0
# 540                                                 []              481.0
#
#       price currency Unnamed: 30
# 280  315000      USD         NaN
# 299  374612      USD         NaN
# 347  390000      USD         NaN
# 354  380000      USD         NaN
# 540  485000      USD         NaN
#
# [5 rows x 28 columns]

# %%
#drop all bathrooms==0
df.dropna(subset=["bedrooms"], inplace=True)

# %%
df[df["bedrooms"] > 20].sort_values(by="bedrooms")
# Out:
#       zipcode             streetAddress      homeType  yearBuilt  \
# 5360    90057        245 S Westlake Ave  MULTI_FAMILY       2023
# 5324    90033            456 S Breed St  MULTI_FAMILY       1972
# 4880    90744    1421 N Wilmington Blvd  MULTI_FAMILY       1957
# 5521    90034            10915 Rose Ave  MULTI_FAMILY       1971
# 5280    91605          13135 Vanowen St  MULTI_FAMILY       1960
# 5378    90016    5110 W Washington Blvd  MULTI_FAMILY       1946
# 5446    90006            1029 Elden Ave  MULTI_FAMILY       1991
# 5466    90003  5869-5875 S San Pedro St  MULTI_FAMILY       2023
# 5299    90044             649 W 92nd St  MULTI_FAMILY       2023
# 3216    90011             637 E 23rd St  MULTI_FAMILY       1957
#
#       lotAreaValue lotAreaUnits  livingAreaValue livingAreaUnitsShort  \
# 5360   1037.633607         sqft      1037.633607                 sqft
# 5324   1751.871871        Acres      1751.871871                 sqft
# 4880   1121.805200        Acres       738.393044                 sqft
# 5521   1899.866350         sqft      1899.866350                 sqft
# 5280   1547.923950        Acres      1399.769501                 sqft
# 5378   2207.157444        Acres      1011.249155                 sqft
# 5446   2024.263467        Acres      2024.263467                 sqft
# 5466   1667.330141        Acres      1667.330141                 sqft
# 5299   1765.240332        Acres      1196.590640                 sqft
# 3216    541.067072         sqft       327.018560                 sqft
#
#       garageParkingCapacity  bedrooms  ...                    sewer  roofType  \
# 5360                    9.0      24.0  ...  ['Conventional Septic']       NaN
# 5324                    0.0      25.0  ...         ['Public Sewer']       NaN
# 4880                   13.0      28.0  ...         ['Public Sewer']       NaN
# 5521                    NaN      31.0  ...                      NaN       NaN
# 5280                    NaN      33.0  ...                      NaN       NaN
# 5378                    NaN      34.0  ...                      NaN       NaN
# 5446                    NaN      36.0  ...                      NaN       NaN
# 5466                    8.0      36.0  ...                      NaN       NaN
# 5299                    NaN      40.0  ...                      NaN       NaN
# 3216                    0.0      72.0  ...         ['Public Sewer']       NaN
#
#       taxAssessedValue  zestimate rentZestimate  \
# 5360         1300499.0        NaN        4347.0
# 5324               NaN  3648500.0        3895.0
# 4880               NaN  2269400.0        3650.0
# 5521               NaN  4982000.0        9254.0
# 5280               NaN  3322900.0        3998.0
# 5378               NaN  3835700.0       14800.0
# 5446               NaN  4727900.0       17865.0
# 5466               NaN  4909600.0       18748.0
# 5299           33084.0        NaN        4146.0
# 3216               NaN  1137300.0        2531.0
#
#                                            sold-history pricePerSquareFoot  \
# 5360  [('2021-04-12', 1250000), ('2019-11-27', 81500...              322.0
# 5324                                                 []              191.0
# 4880                                                 []              283.0
# 5521                                                 []              243.0
# 5280                                                 []              217.0
# 5378                                                 []              345.0
# 5446                                                 []              211.0
# 5466                                                 []              267.0
# 5299     [('2018-01-02', 630000), ('1986-10-29', 5500)]              267.0
# 3216                                                 []              313.0
#
#         price currency Unnamed: 30
# 5360  3600000      USD         NaN
# 5324  3600000      USD         NaN
# 4880  2250000      USD         NaN
# 5521  4975000      USD         NaN
# 5280  3264000      USD         NaN
# 5378  3750000      USD         NaN
# 5446  4600000      USD         NaN
# 5466  4800000      USD         NaN
# 5299  3445000      USD         NaN
# 3216  1100000      USD         NaN
#
# [10 rows x 28 columns]

# %%
df["bedrooms"].isna().sum()
# Out:
# 0

# %%
df["bedrooms"] = df["bedrooms"].astype(int)

# %%
df[df["bedrooms"] ==0]
# Out:
#       zipcode                  streetAddress       homeType  yearBuilt  \
# 136     90015                 1421 Albany St  SINGLE_FAMILY       1903
# 238     91316    5325 Newcastle Ave UNIT 128          CONDO       1971
# 315     90012          800 W 1st St APT 1604          CONDO       1968
# 341     90015           645 W 9th St APT 405          CONDO       2006
# 360     90031  200 N San Fernando Rd APT 211          CONDO       1925
# 371     90046     7250 Franklin Ave UNIT 711          CONDO       1964
# 379     90013           825 E 4th St APT 109          CONDO       1923
# 383     90012         257 S Spring St APT 4L          CONDO       1899
# 387     90014          215 W 7th St APT 1303          CONDO       1911
# 409     90013     420 S San Pedro St APT 213          CONDO       1922
# 468     90731           285 W 6th St APT 310          CONDO       2006
# 471     90014  746 S Los Angeles St APT 1103          CONDO       1922
# 477     90005      620 S Gramercy Pl APT 431          CONDO       1990
# 493     90017       877 Francisco St APT 819          CONDO       2017
# 576     90028            1645 N Vine St #501          CONDO       1928
# 596     90037                  829 W 56th St  SINGLE_FAMILY       1922
# 1260    91406                  15322 Hart St            LOT       1938
# 2872    90013       510 S Hewitt St UNIT 515          CONDO       1966
# 4530    91042             7157 Foothill Blvd  SINGLE_FAMILY       1947
#
#       lotAreaValue lotAreaUnits  livingAreaValue livingAreaUnitsShort  \
# 136   5.584399e+02         sqft       190.544053                 sqft
# 238   9.585393e+03        Acres        44.872149                 sqft
# 315   9.874338e+03        Acres        44.686343                 sqft
# 341   6.943602e+03        Acres        61.315980                 sqft
# 360   5.868352e+03        Acres        62.245010                 sqft
# 371   4.973186e+03        Acres        49.796008                 sqft
# 379   4.011652e+03        Acres        61.315980                 sqft
# 383   2.677403e+03        Acres        60.386950                 sqft
# 387   1.479575e+03        Acres        58.528890                 sqft
# 409   7.099002e+03        Acres        72.464340                 sqft
# 468   5.621089e+03        Acres        77.109490                 sqft
# 471   3.558809e+03        Acres        71.535310                 sqft
# 477   4.789459e+03        Acres        55.927606                 sqft
# 493   1.198073e+04        Acres        47.473433                 sqft
# 576   2.091013e+03        Acres        99.406210                 sqft
# 596   4.756634e+02         sqft       157.563488                 sqft
# 1260  6.503210e+02         sqft       189.150508                 sqft
# 2872  2.164665e+03        Acres       123.560990                 sqft
# 4530  5.495231e+07        Acres       451.880192                 sqft
#
#       garageParkingCapacity  bedrooms  ...                sewer     roofType  \
# 136                     NaN         0  ...                  NaN          NaN
# 238                     1.0         0  ...     ['Public Sewer']          NaN
# 315                     1.0         0  ...  ['Sewer Connected']  Composition
# 341                     1.0         0  ...     ['Public Sewer']  Common Roof
# 360                     1.0         0  ...        ['In Street']          NaN
# 371                     NaN         0  ...                  NaN          NaN
# 379                     NaN         0  ...                  NaN          NaN
# 383                     1.0         0  ...                  NaN          NaN
# 387                     0.0         0  ...     ['Public Sewer']          NaN
# 409                     1.0         0  ...        ['In Street']          NaN
# 468                     2.0         0  ...     ['Public Sewer']          NaN
# 471                     NaN         0  ...                  NaN          NaN
# 477                     NaN         0  ...                  NaN          NaN
# 493                     NaN         0  ...                  NaN          NaN
# 576                     NaN         0  ...                  NaN          NaN
# 596                     NaN         0  ...                  NaN        Other
# 1260                    NaN         0  ...                  NaN          NaN
# 2872                    NaN         0  ...                  NaN          NaN
# 4530                    NaN         0  ...                  NaN          NaN
#
#       taxAssessedValue  zestimate rentZestimate  \
# 136           551843.0   700600.0        1614.0
# 238           273409.0   306000.0        1702.0
# 315           131776.0   371600.0        2238.0
# 341           369713.0   405900.0        2441.0
# 360           285719.0   400700.0        2350.0
# 371           440627.0   432000.0        2195.0
# 379           347971.0   421900.0        2557.0
# 383           121000.0   417400.0        2314.0
# 387           146000.0   434700.0        2394.0
# 409           449000.0   430100.0        2299.0
# 468           348036.0   466400.0        2495.0
# 471           159000.0   462600.0        2317.0
# 477           419957.0   466700.0        2008.0
# 493                NaN   476100.0        2299.0
# 576           225000.0   489000.0        3333.0
# 596           347579.0   511400.0        1755.0
# 1260          367911.0        NaN        1999.0
# 2872          994500.0   991400.0        3692.0
# 4530         1343340.0  1772000.0        2650.0
#
#                                            sold-history pricePerSquareFoot  \
# 136                            [('2015-11-23', 485000)]               32.0
# 238    [('2019-06-25', 255000), ('2006-01-24', 199000)]              621.0
# 315      [('2018-08-31', 21000), ('2000-01-20', 91000)]              759.0
# 341                            [('2010-02-01', 298000)]              606.0
# 360    [('2014-05-16', 242500), ('2013-06-19', 199000)]              596.0
# 371    [('2017-05-03', 395000), ('2013-03-22', 210000)]              794.0
# 379                            [('2013-01-24', 239000)]              644.0
# 383        [('2016-11-30', 2000), ('2016-08-19', 2150)]              631.0
# 387     [('2011-02-01', 132000), ('2010-10-12', 93273)]              675.0
# 409                            [('2006-08-25', 392000)]              538.0
# 468                            [('2007-10-10', 380000)]              548.0
# 471                            [('2016-11-30', 485000)]              591.0
# 477    [('2023-07-13', 450000), ('2017-12-01', 384000)]              764.0
# 493                                                  []              930.0
# 576                            [('2018-08-03', 610000)]              466.0
# 596    [('2013-08-07', 295000), ('2012-10-26', 487987)]              295.0
# 1260  [('2019-08-09', 1128280), ('2017-03-16', 12000...              332.0
# 2872                           [('2022-03-17', 975000)]              744.0
# 4530                          [('2021-12-01', 2200000)]              364.0
#
#         price currency Unnamed: 30
# 136     66500      USD         NaN
# 238    300000      USD         NaN
# 315    365000      USD         NaN
# 341    400000      USD         NaN
# 360    399000      USD         NaN
# 371    425500      USD         NaN
# 379    425000      USD         NaN
# 383    410000      USD         NaN
# 387    425000      USD         NaN
# 409    420000      USD         NaN
# 468    455000      USD         NaN
# 471    455000      USD         NaN
# 477    460000      USD         NaN
# 493    475000      USD         NaN
# 576    499000      USD         NaN
# 596    500000      USD         NaN
# 1260   675000      USD         NaN
# 2872   990000      USD         NaN
# 4530  1770000      USD         NaN
#
# [19 rows x 28 columns]

# %%
df.drop(index=[136,596,4530]	, inplace=True)

# %%
df.drop(columns = ["lotAreaUnits", "livingAreaUnitsShort"], inplace=True)

# %%
df.head()
# Out:
#    zipcode                 streetAddress       homeType  yearBuilt  \
# 0    90049     11645 Montana Ave APT 229          CONDO       1973
# 2    91406           6452 Woodley Ave #3      APARTMENT       2006
# 5    90066  4040 Grand View Blvd UNIT 15      TOWNHOUSE       1961
# 6    91303        7305 Milwood Ave APT 3          CONDO       1981
# 8    91040              8701 Hillrose St  SINGLE_FAMILY       1945
#
#    lotAreaValue  livingAreaValue  garageParkingCapacity  bedrooms  bathrooms  \
# 0   4645.390594        79.432065                    2.0         1        1.0
# 2           NaN       167.225400                    NaN         3        2.5
# 5  11561.886452        78.131423                    NaN         2        1.5
# 6     90.301716        90.301716                    NaN         2        1.0
# 8   7098.170143       129.320976                    NaN         2        1.5
#
#    bathroomsFull  ...             sewer roofType taxAssessedValue zestimate  \
# 0            1.0  ...  ['Public Sewer']      NaN         699000.0  701200.0
# 2            0.0  ...               NaN      NaN              NaN  690500.0
# 5            0.0  ...               NaN    Other         512017.0  734100.0
# 6            NaN  ...               NaN      NaN         105445.0  464800.0
# 8            0.0  ...               NaN      NaN          68036.0  759600.0
#
#   rentZestimate                                       sold-history  \
# 0        2999.0                           [('2022-08-12', 699000)]
# 2        2634.0                                                 []
# 5        3997.0   [('2015-10-21', 450000), ('2005-04-07', 396000)]
# 6        3499.0  [('2009-11-13', 85000), ('2007-04-18', 299000)...
# 8        3781.0       [('2021-06-29', 3350), ('2019-01-22', 3150)]
#
#   pricePerSquareFoot price  currency  Unnamed: 30
# 0                4.0  3050       USD          NaN
# 2                2.0  3500       USD          NaN
# 5                4.0  3100       USD          NaN
# 6                3.0  2800       USD          NaN
# 8                3.0  3600       USD          NaN
#
# [5 rows x 26 columns]

# %%
df[df["bathrooms"] == 0]
# Out:
#       zipcode       streetAddress      homeType  yearBuilt  lotAreaValue  \
# 235     90003      6007 S Main St  MULTI_FAMILY       1911    526.016786
# 460     90032     4502 Lowell Ave           LOT       1922    695.564761
# 1260    91406       15322 Hart St           LOT       1938    650.321000
# 1876    91405  6826 Hazeltine Ave           LOT       1946    488.019459
# 1901    90063    520 S Concord St  MULTI_FAMILY       1917    538.187079
# 2245    90044  624 W Imperial Hwy           LOT       1939    822.284453
# 3118    90018      2216 S 8th Ave  MULTI_FAMILY       2008    464.515000
# 3650    91601    11343 Miranda St           LOT       1923   1275.559867
# 3860    90044  8886 S Vermont Ave           LOT       1951    997.127899
# 4459    91436  16879 Mooncrest Dr           LOT       1955   1022.213053
# 5322    90027   2718 Hyperion Ave  MULTI_FAMILY       1918   2150.893084
#
#       livingAreaValue  garageParkingCapacity  bedrooms  bathrooms  \
# 235        163.137668                    NaN         5        0.0
# 460         58.435987                    NaN         2        0.0
# 1260       189.150508                    NaN         0        0.0
# 1876        64.846294                    NaN         2        0.0
# 1901       125.976468                    NaN         4        0.0
# 2245       161.279608                    NaN         5        0.0
# 3118       213.676900                    NaN         8        0.0
# 3650       109.625540                    NaN         3        0.0
# 3860       206.058854                    NaN         2        0.0
# 4459       157.935100                    NaN         2        0.0
# 5322       313.733431                    NaN         5        0.0
#
#       bathroomsFull  ...  sewer         roofType taxAssessedValue  zestimate  \
# 235             NaN  ...    NaN              NaN         387892.0   273500.0
# 460             0.0  ...    NaN              NaN         204979.0   620400.0
# 1260            0.0  ...    NaN              NaN         367911.0        NaN
# 1876            0.0  ...    NaN              NaN         639846.0        NaN
# 1901            0.0  ...    NaN  Shake / Shingle         539349.0   793000.0
# 2245            0.0  ...    NaN              NaN         531435.0        NaN
# 3118            0.0  ...    NaN            Other         944394.0  1096900.0
# 3650            0.0  ...    NaN              NaN        3510695.0  1231600.0
# 3860            0.0  ...    NaN            Other         781954.0        NaN
# 4459            0.0  ...    NaN            Other        1275000.0        NaN
# 5322            3.0  ...    NaN            Other        3626564.0  3285200.0
#
#      rentZestimate                                       sold-history  \
# 235         3399.0  [('2003-11-17', 245000), ('2002-07-18', 86500)...
# 460         2325.0  [('2020-05-11', 110000), ('2019-01-22', 20000)...
# 1260        1999.0  [('2019-08-09', 1128280), ('2017-03-16', 12000...
# 1876        2995.0   [('2021-06-08', 615000), ('2017-03-31', 385000)]
# 1901        3264.0  [('2016-12-30', 483500), ('2016-03-12', 320000...
# 2245        3699.0  [('2020-07-31', 511000), ('2019-09-09', 521000...
# 3118        3232.0   [('2016-06-17', 830000), ('2012-04-25', 450000)]
# 3650        4764.0  [('2015-12-07', 535000), ('1997-03-31', 137000...
# 3860        2650.0   [('2017-10-17', 715000), ('2016-03-29', 470000)]
# 4459        5695.0  [('2021-11-19', 1250000), ('2015-10-16', 955000)]
# 5322       13598.0                          [('2019-12-23', 3450000)]
#
#      pricePerSquareFoot    price  currency  Unnamed: 30
# 235               154.0   270000       USD          NaN
# 460               716.0   450500       USD          NaN
# 1260              332.0   675000       USD          NaN
# 1876             1117.0   780000       USD          NaN
# 1901              582.0   789000       USD          NaN
# 2245              493.0   855000       USD          NaN
# 3118              471.0  1083000       USD          NaN
# 3650             1076.0  1270000       USD          NaN
# 3860              609.0  1350000       USD          NaN
# 4459             1029.0  1750000       USD          NaN
# 5322             1036.0  3500000       USD          NaN
#
# [11 rows x 26 columns]

# %%
df = df[(df["bathrooms"] != 0) | (df["homeType"] == "LOT")]

# %%
df["bathrooms"].isna().sum()
# Out:
# 11

# %%
#drop null bathrooms
df.dropna(subset=["bathrooms"], inplace=True)

# %%
#drop column bathroomsfull
df.drop(columns=["bathroomsFull"], inplace=True)

# %%
df["stories"].value_counts()
# Out:
# stories
# 1.0     2366
# 2.0     1186
# 3.0      393
# 4.0      121
# 5.0       27
# 22.0      12
# 6.0       11
# 13.0       8
# 11.0       6
# 18.0       6
# 8.0        6
# 23.0       6
# 16.0       4
# 24.0       4
# 19.0       4
# 21.0       4
# 10.0       3
# 14.0       3
# 7.0        3
# 15.0       2
# 17.0       2
# 20.0       2
# 32.0       2
# 29.0       2
# 27.0       2
# 25.0       1
# 39.0       1
# 28.0       1
# 52.0       1
# 54.0       1
# 42.0       1
# Name: count, dtype: int64

# %%
df[(df["stories"].isna())&(df["homeType"]=="LOT")]
#replace null stories with 0 for LOT
# Out:
#       zipcode       streetAddress homeType  yearBuilt  lotAreaValue  \
# 460     90032     4502 Lowell Ave      LOT       1922    695.564761
# 1260    91406       15322 Hart St      LOT       1938    650.321000
# 1876    91405  6826 Hazeltine Ave      LOT       1946    488.019459
# 2245    90044  624 W Imperial Hwy      LOT       1939    822.284453
# 3650    91601    11343 Miranda St      LOT       1923   1275.559867
# 3860    90044  8886 S Vermont Ave      LOT       1951    997.127899
# 4459    91436  16879 Mooncrest Dr      LOT       1955   1022.213053
#
#       livingAreaValue  garageParkingCapacity  bedrooms  bathrooms  stories  \
# 460         58.435987                    NaN         2        0.0      NaN
# 1260       189.150508                    NaN         0        0.0      NaN
# 1876        64.846294                    NaN         2        0.0      NaN
# 2245       161.279608                    NaN         5        0.0      NaN
# 3650       109.625540                    NaN         3        0.0      NaN
# 3860       206.058854                    NaN         2        0.0      NaN
# 4459       157.935100                    NaN         2        0.0      NaN
#
#       ... sewer roofType taxAssessedValue  zestimate rentZestimate  \
# 460   ...   NaN      NaN         204979.0   620400.0        2325.0
# 1260  ...   NaN      NaN         367911.0        NaN        1999.0
# 1876  ...   NaN      NaN         639846.0        NaN        2995.0
# 2245  ...   NaN      NaN         531435.0        NaN        3699.0
# 3650  ...   NaN      NaN        3510695.0  1231600.0        4764.0
# 3860  ...   NaN    Other         781954.0        NaN        2650.0
# 4459  ...   NaN    Other        1275000.0        NaN        5695.0
#
#                                            sold-history pricePerSquareFoot  \
# 460   [('2020-05-11', 110000), ('2019-01-22', 20000)...              716.0
# 1260  [('2019-08-09', 1128280), ('2017-03-16', 12000...              332.0
# 1876   [('2021-06-08', 615000), ('2017-03-31', 385000)]             1117.0
# 2245  [('2020-07-31', 511000), ('2019-09-09', 521000...              493.0
# 3650  [('2015-12-07', 535000), ('1997-03-31', 137000...             1076.0
# 3860   [('2017-10-17', 715000), ('2016-03-29', 470000)]              609.0
# 4459  [('2021-11-19', 1250000), ('2015-10-16', 955000)]             1029.0
#
#         price  currency  Unnamed: 30
# 460    450500       USD          NaN
# 1260   675000       USD          NaN
# 1876   780000       USD          NaN
# 2245   855000       USD          NaN
# 3650  1270000       USD          NaN
# 3860  1350000       USD          NaN
# 4459  1750000       USD          NaN
#
# [7 rows x 25 columns]

# %%
df.loc[(df["stories"].isna())&(df["homeType"]=="LOT"), "stories"] = 0

# %%
df[df["stories"].isna()]["homeType"].value_counts()
#set null stories based on hometypes and each story
# Out:
# homeType
# SINGLE_FAMILY    536
# CONDO            267
# MULTI_FAMILY     128
# TOWNHOUSE         40
# APARTMENT         24
# MANUFACTURED       5
# Name: count, dtype: int64

# %%
df["flooring"].value_counts()
# Out:
# flooring
# []                                                                       422
# ['Wood']                                                                 286
# ['Hardwood']                                                             273
# ['Laminate']                                                             259
# ['Tile', 'Wood']                                                         151
#                                                                         ...
# ['See Remarks', 'Tile', 'Wood']                                            1
# ['Other', 'Porcelain', 'Engineered Hardwood', 'Stone Tile', 'Marble']      1
# ['Ceramic Tile', 'Other', 'Laminate', 'Granite']                           1
# ['Concrete', 'Wood', 'Tile']                                               1
# ['Tile', 'Hardwood', 'Stone', 'Stone Tile']                                1
# Name: count, Length: 585, dtype: int64

# %%
df["flooring"].fillna("[]", inplace=True)
# Out:
# C:\Users\minas\AppData\Local\Temp\ipykernel_2244\3518925771.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["flooring"].fillna("[]", inplace=True)

# %%
import ast
df['flooring']=df['flooring'].apply(ast.literal_eval)

# %%
all_values = [item for sublist in df['flooring'] for item in sublist]
unique_values = set(all_values)
unique_values
# Out:
# {'Bamboo',
#  'Brick',
#  'Carpet',
#  'Cement',
#  'Ceramic Tile',
#  'Clay',
#  'Concrete',
#  'Engineered Hardwood',
#  'Granite',
#  'Hardwood',
#  'Hardwood Flrs Throughout',
#  'In Need Of Repair',
#  'Laminate',
#  'Linoleum',
#  'Linoleum / Vinyl',
#  'Marble',
#  'Mixed',
#  'Other',
#  'Parquet',
#  'Pavers',
#  'Porcelain',
#  'See Remarks',
#  'Slate',
#  'Stained Concrete',
#  'Stone',
#  'Stone Tile',
#  'Terrazzo',
#  'Tile',
#  'Travertine',
#  'Vinyl',
#  'Vinyl Plank',
#  'Vinyl Sheet',
#  'Vinyl Tile',
#  'Wood',
#  'Wood Laminate',
#  'Wood Under Carpet'}

# %%
#check how may flooring is empty
df[df["flooring"].apply(len) == 0]
# Out:
#       zipcode             streetAddress       homeType  yearBuilt  \
# 6       91303    7305 Milwood Ave APT 3          CONDO       1981
# 8       91040          8701 Hillrose St  SINGLE_FAMILY       1945
# 10      91325  17123 Roscoe Blvd UNIT 2      APARTMENT       1971
# 12      91605      7920 Saint Clair Ave  SINGLE_FAMILY       1948
# 24      91601            5738 Denny Ave  SINGLE_FAMILY       1975
# ...       ...                       ...            ...        ...
# 5559    90272            1117 Kagawa St  SINGLE_FAMILY       2007
# 5566    90049      12319 18th Helena Dr  SINGLE_FAMILY       1948
# 5581    90004          4804 Oakwood Ave      APARTMENT       2022
# 5583    90069       1896 Rising Glen Rd  SINGLE_FAMILY       1959
# 5600    91436           4550 Libbit Ave  SINGLE_FAMILY       1951
#
#       lotAreaValue  livingAreaValue  garageParkingCapacity  bedrooms  \
# 6        90.301716        90.301716                    NaN         2
# 8      7098.170143       129.320976                    NaN         2
# 10    30031.677454       127.091304                    NaN         3
# 12      724.364691        88.257850                    NaN         2
# 24      930.702254       125.419050                    NaN         3
# ...            ...              ...                    ...       ...
# 5559    603.869500       320.608253                    NaN         5
# 5566   1263.389558       181.532462                    NaN         2
# 5581   2709.608898      2709.608898                    NaN         6
# 5583   5948.865619       420.757687                    NaN         4
# 5600   3829.559597       415.740925                    NaN         5
#
#       bathrooms  stories  ...        sewer     roofType taxAssessedValue  \
# 6           1.0      NaN  ...          NaN          NaN         105445.0
# 8           1.5      NaN  ...          NaN          NaN          68036.0
# 10          2.0      NaN  ...          NaN        Other         169009.0
# 12          2.0      NaN  ...          NaN          NaN              NaN
# 24          2.0      NaN  ...          NaN          NaN         462057.0
# ...         ...      ...  ...          ...          ...              ...
# 5559        6.0      NaN  ...          NaN          NaN        3612603.0
# 5566        2.0      NaN  ...  ['On Site']  Composition        3468000.0
# 5581        4.0      NaN  ...          NaN          NaN        9012458.0
# 5583        5.0      NaN  ...          NaN          NaN       12518882.0
# 5600        5.0      NaN  ...          NaN          NaN        4182000.0
#
#        zestimate rentZestimate  \
# 6       464800.0        3499.0
# 8       759600.0        3781.0
# 10      498300.0        3170.0
# 12      743900.0        2996.0
# 24      772800.0        1884.0
# ...          ...           ...
# 5559   6572100.0       25289.0
# 5566   5686500.0       20083.0
# 5581         NaN       48858.0
# 5583  23260200.0       68766.0
# 5600  19157400.0       20503.0
#
#                                            sold-history pricePerSquareFoot  \
# 6     [('2009-11-13', 85000), ('2007-04-18', 299000)...                3.0
# 8          [('2021-06-29', 3350), ('2019-01-22', 3150)]                3.0
# 10    [('2011-11-28', 140000), ('2011-09-16', 151300...                2.0
# 12                               [('2023-05-05', 3000)]                3.0
# 24    [('2012-08-29', 335000), ('2003-09-08', 359000...                1.0
# ...                                                 ...                ...
# 5559  [('2015-12-22', 3175000), ('2007-03-09', 31000...             1869.0
# 5566                          [('2021-11-23', 3400000)]             3214.0
# 5581                                                 []              461.0
# 5583  [('2017-09-14', 11200000), ('2007-11-30', 6600...            13248.0
# 5600  [('2022-02-03', 4100000), ('1994-03-24', 64500...             4246.0
#
#          price  currency  Unnamed: 30
# 6         2800       USD          NaN
# 8         3600       USD          NaN
# 10        3100       USD          NaN
# 12        3100       USD          NaN
# 24        1950       USD          NaN
# ...        ...       ...          ...
# 5559   6450000       USD          NaN
# 5566   6280000       USD          NaN
# 5581  13450000       USD          NaN
# 5583  60000000       USD          NaN
# 5600  19000000       USD          NaN
#
# [1772 rows x 25 columns]

# %%
df["heating"].fillna("[]", inplace=True)
# Out:
# C:\Users\minas\AppData\Local\Temp\ipykernel_2244\3888303789.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["heating"].fillna("[]", inplace=True)

# %%
import ast
df['heating']=df['heating'].apply(ast.literal_eval)

# %%
df[df["heating"]=="['Other']"]
# Out:
# Empty DataFrame
# Columns: [zipcode, streetAddress, homeType, yearBuilt, lotAreaValue, livingAreaValue, garageParkingCapacity, bedrooms, bathrooms, stories, flooring, foundationDetails, heating, cooling, fireplaceFeatures, sewer, roofType, taxAssessedValue, zestimate, rentZestimate, sold-history, pricePerSquareFoot, price, currency, Unnamed: 30]
# Index: []
#
# [0 rows x 25 columns]

# %%
all_values = [item for sublist in df['heating'] for item in sublist]
unique_values = set(all_values)
unique_values
# Out:
# {'Baseboard',
#  'Central',
#  'Central Forced Air',
#  'Central Heat/Gas',
#  'Combination',
#  'Ductless',
#  'ENERGY STAR Qualified Equipment',
#  'Electric',
#  'Fireplace(s)',
#  'Floor Furnace',
#  'Forced Air',
#  'Forced air',
#  'Gas',
#  'Geothermal',
#  'Gravity',
#  'Has Heating (Unspecified Type)',
#  'Heat Pump',
#  'Heat pump',
#  'High Efficiency',
#  'Hot Water',
#  'Natural Gas',
#  'None',
#  'Other',
#  'Other Heat Source (See Remarks)',
#  'Passive Solar',
#  'Propane',
#  'Radiant',
#  'See Remarks',
#  'Solar',
#  'Solar Heat Other',
#  'Space Heater',
#  'Stove',
#  'Wall',
#  'Wall Electric',
#  'Wall Furnace',
#  'Wall Gas',
#  'Wood',
#  'Zoned',
#  'central',
#  'wood'}

# %%
df.drop(columns=["foundationDetails"], inplace=True)

# %%
df["cooling"].fillna("[]", inplace=True)
# Out:
# C:\Users\minas\AppData\Local\Temp\ipykernel_2244\2171616711.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["cooling"].fillna("[]", inplace=True)

# %%
import ast
df['cooling']=df['cooling'].apply(ast.literal_eval)

# %%
all_values = [item for sublist in df['cooling'] for item in sublist]
unique_values = set(all_values)
unique_values
# Out:
# {'Air Conditioning',
#  'Attic Fan',
#  'Ceiling Fan(s)',
#  'Central',
#  'Central Air',
#  'Central Air/Evap',
#  'Central Air/Refrig',
#  'Central Forced Air',
#  'Dual',
#  'Ductless',
#  'ENERGY STAR Qualified Equipment',
#  'Electric',
#  'Evaporative',
#  'Evaporative Cooling',
#  'Gas',
#  'Heat Pump',
#  'High Efficiency',
#  'None',
#  'Other',
#  'Refridge Wall/Window',
#  'Refrigerator',
#  'SEER Rated 13-15',
#  'SEER Rated 16+',
#  'See Remarks',
#  'Solar',
#  'Swamp Cooler(s)',
#  'Wall',
#  'Wall A/C Units',
#  'Wall Unit(s)',
#  'Wall/Window Unit(s)',
#  'Whole House Fan',
#  'Window Unit(s)',
#  'Zoned'}

# %%
df["fireplaceFeatures"].isna().sum()
# Out:
# 906

# %%
df["fireplaceFeatures"].value_counts()
# Out:
# fireplaceFeatures
# ['None']                                                                      1513
# ['Living Room']                                                               1127
# ['Family Room']                                                                215
# ['Living Room', 'Gas']                                                         132
# ['Decorative']                                                                  88
#                                                                               ...
# ['Living Room', 'Raised Hearth', 'See Remarks']                                  1
# ['Living Room', 'Gas', 'Gas Starter', 'Wood Burning', 'Masonry']                 1
# ['Living Room', 'Gas Starter', 'Wood Burning', 'Masonry', 'Raised Hearth']       1
# ['Master Bedroom', 'Den']                                                        1
# ['Master Bedroom', 'Gas', 'Family Room', 'Outside']                              1
# Name: count, Length: 435, dtype: int64

# %%
df["fireplaceFeatures"].fillna("[]", inplace=True)
# Out:
# C:\Users\minas\AppData\Local\Temp\ipykernel_2244\3311353336.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["fireplaceFeatures"].fillna("[]", inplace=True)

# %%
import ast
df['fireplaceFeatures']=df['fireplaceFeatures'].apply(ast.literal_eval)

# %%
all_values = [item for sublist in df['fireplaceFeatures'] for item in sublist]
unique_values = set(all_values)
unique_values
# Out:
# {'Bath',
#  'Blower Fan',
#  'Bonus Room',
#  'Circular',
#  'Decorative',
#  'Deleted At Main Hous',
#  'Den',
#  'Dining Room',
#  'Double Sided',
#  'Electric',
#  'Family Room',
#  'Fire Pit',
#  'Free Standing',
#  'Game Room',
#  'Gas',
#  'Gas Starter',
#  'Gas and Wood',
#  'Great Room',
#  'Guest House',
#  'Heatilator',
#  'Kitchen',
#  'Library',
#  'Living Room',
#  'Masonry',
#  'Master Bedroom',
#  'Master Retreat',
#  'None',
#  'Other',
#  'Other/Remarks',
#  'Outside',
#  'Patio',
#  'Propane',
#  'Raised Hearth',
#  'See Remarks',
#  'See Through',
#  'Wood Burning',
#  'Wood Stove Insert',
#  'Woodburning'}

# %%
df[df["fireplaceFeatures"]=="['See Remarks']"]
# Out:
# Empty DataFrame
# Columns: [zipcode, streetAddress, homeType, yearBuilt, lotAreaValue, livingAreaValue, garageParkingCapacity, bedrooms, bathrooms, stories, flooring, heating, cooling, fireplaceFeatures, sewer, roofType, taxAssessedValue, zestimate, rentZestimate, sold-history, pricePerSquareFoot, price, currency, Unnamed: 30]
# Index: []
#
# [0 rows x 24 columns]

# %%
values_to_remove = {'None', 'See Remarks','See Through','Deleted At Main Hous'}

# Function to remove specific values from the lists
def remove_values(lst, values_to_remove):
    return [item for item in lst if item not in values_to_remove]

# Apply the function to the DataFrame column
df['fireplaceFeatures'] = df['fireplaceFeatures'].apply(lambda x: remove_values(x, values_to_remove))

# %%
all_values = [item for sublist in df['fireplaceFeatures'] for item in sublist]
unique_values = set(all_values)
unique_values
# Out:
# {'Bath',
#  'Blower Fan',
#  'Bonus Room',
#  'Circular',
#  'Decorative',
#  'Den',
#  'Dining Room',
#  'Double Sided',
#  'Electric',
#  'Family Room',
#  'Fire Pit',
#  'Free Standing',
#  'Game Room',
#  'Gas',
#  'Gas Starter',
#  'Gas and Wood',
#  'Great Room',
#  'Guest House',
#  'Heatilator',
#  'Kitchen',
#  'Library',
#  'Living Room',
#  'Masonry',
#  'Master Bedroom',
#  'Master Retreat',
#  'Other',
#  'Other/Remarks',
#  'Outside',
#  'Patio',
#  'Propane',
#  'Raised Hearth',
#  'Wood Burning',
#  'Wood Stove Insert',
#  'Woodburning'}

# %%
#convert all non-empty fireplaceFeatures to 1
df['fireplaceFeatures'] = df['fireplaceFeatures'].apply(lambda x: 1 if len(x) > 0 else 0)

# %%
df["fireplaceFeatures"].value_counts()
# Out:
# fireplaceFeatures
# 1    2743
# 0    2455
# Name: count, dtype: int64

# %%
df.drop(columns=["sewer"], inplace=True)

# %%
df["roofType"].value_counts()
# Out:
# roofType
# Composition                           298
# Shingle                               203
# Composition,Shingle                   145
# Asphalt                                84
# Tile                                   81
#                                      ...
# Composition,Rolled/Hot Mop              1
# Foam                                    1
# Elastomeric,Flat,Spanish Tile,Tile      1
# Rolled/Hot Mop,Spanish Tile             1
# Composition,Metal,Shingle               1
# Name: count, Length: 105, dtype: int64

# %%
df["roofType"].isna().sum()
# Out:
# 3965

# %%
df.drop(columns=["roofType"], inplace=True)

# %%
df["taxAssessedValue"].isna().sum()
# Out:
# 306

# %%
df["taxAssessedValue"].describe()
# Out:
# count    4.892000e+03
# mean     7.922438e+05
# std      1.150000e+06
# min      9.010000e+03
# 25%      2.477375e+05
# 50%      5.255875e+05
# 75%      9.020122e+05
# max      2.264544e+07
# Name: taxAssessedValue, dtype: float64

# %%
#fill null taxAssessedValue with median
df["taxAssessedValue"].fillna(df["taxAssessedValue"].median(), inplace=True)
# Out:
# C:\Users\minas\AppData\Local\Temp\ipykernel_2244\2270976764.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["taxAssessedValue"].fillna(df["taxAssessedValue"].median(), inplace=True)

# %%
df["taxAssessedValue"].isna().sum()
# Out:
# 0

# %%
df["zestimate"].isna().sum()
# Out:
# 261

# %%
df["rentZestimate"].isna().sum()
# Out:
# 1

# %%
df["sold-history"].isna().sum()
# Out:
# 0

# %%
df[df["sold-history"]=="[]"]
# Out:
#       zipcode               streetAddress       homeType  yearBuilt  \
# 2       91406         6452 Woodley Ave #3      APARTMENT       2006
# 13      91405          14735 Runnymede St  SINGLE_FAMILY       1940
# 15      90402  109 Chautauqua Blvd APT 14          CONDO       1924
# 17      90035           1574 Glenville Dr  SINGLE_FAMILY       1929
# 23      91423      14061 Milbank St APT 2      TOWNHOUSE       1999
# ...       ...                         ...            ...        ...
# 5580    90210        11 Beverly Ridge Ter  SINGLE_FAMILY       2006
# 5581    90004            4804 Oakwood Ave      APARTMENT       2022
# 5591    90272            1457 San Remo Dr  SINGLE_FAMILY       1953
# 5593    90049              1498 Moraga Dr  SINGLE_FAMILY       1981
# 5601    90077                825 Nimes Pl  SINGLE_FAMILY       1952
#
#       lotAreaValue  livingAreaValue  garageParkingCapacity  bedrooms  \
# 2              NaN       167.225400                    NaN         3
# 13             NaN       102.193300                    NaN         3
# 15             NaN              NaN                    NaN         1
# 17      373.841672        74.322400                    NaN         1
# 23             NaN              NaN                    NaN         2
# ...            ...              ...                    ...       ...
# 5580  12688.524844      1209.039642                    7.0         6
# 5581   2709.608898      2709.608898                    NaN         6
# 5591   1939.255312       417.041567                    NaN         5
# 5593   2243.174498       990.810495                    4.0         6
# 5601   2832.337484       557.418000                    NaN         5
#
#       bathrooms  stories  ...                    cooling fireplaceFeatures  \
# 2           2.5      NaN  ...                  [Central]                 0
# 13          2.0      NaN  ...                  [Central]                 0
# 15          1.0      NaN  ...                     [None]                 0
# 17          1.0      NaN  ...                     [None]                 0
# 23          2.5      NaN  ...                  [Central]                 0
# ...         ...      ...  ...                        ...               ...
# 5580       10.0      2.0  ...              [Central Air]                 1
# 5581        4.0      NaN  ...                  [Central]                 0
# 5591        5.0      1.0  ...                     [Dual]                 1
# 5593        7.0      2.0  ...  [Air Conditioning, Zoned]                 1
# 5601        6.0      NaN  ...                  [Central]                 0
#
#      taxAssessedValue   zestimate  rentZestimate  sold-history  \
# 2            525587.5    690500.0         2634.0            []
# 13           525587.5    555200.0         3196.0            []
# 15           525587.5         NaN         6111.0            []
# 17           785333.0    942200.0         3672.0            []
# 23           525587.5    688400.0         3001.0            []
# ...               ...         ...            ...           ...
# 5580       11156546.0  23511800.0       101604.0            []
# 5581        9012458.0         NaN        48858.0            []
# 5591        1949352.0   9537400.0        37762.0            []
# 5593        6490276.0   9952800.0        34953.0            []
# 5601        2511903.0         NaN        44867.0            []
#
#       pricePerSquareFoot     price  currency  Unnamed: 30
# 2                    2.0      3500       USD          NaN
# 13                   3.0      3250       USD          NaN
# 15                   NaN      2990       USD          NaN
# 17                   3.0      2745       USD          NaN
# 23                   NaN      3295       USD          NaN
# ...                  ...       ...       ...          ...
# 5580              1806.0  23500000       USD          NaN
# 5581               461.0  13450000       USD          NaN
# 5591              2116.0   9500000       USD          NaN
# 5593               933.0   9950000       USD          NaN
# 5601              2667.0  16000000       USD          NaN
#
# [1596 rows x 22 columns]

# %%
import ast
df['sold-history']=df['sold-history'].apply(ast.literal_eval)

# %%
df.drop(columns=["pricePerSquareFoot"], inplace=True)

# %%
df["currency"].value_counts()
# Out:
# currency
# USD    5198
# Name: count, dtype: int64

# %%
df.drop(columns=["currency"], inplace=True)

# %%
df["price"].isna().sum()
# Out:
# 0

# %%
df["price"].describe()
# Out:
# count    5.198000e+03
# mean     1.402406e+06
# std      1.697592e+06
# min      1.950000e+03
# 25%      7.150000e+05
# 50%      9.887500e+05
# 75%      1.550000e+06
# max      6.000000e+07
# Name: price, dtype: float64

# %%
missing_index = df['rentZestimate'].isna()
missing_price = df.loc[missing_index, 'price'].values[0]

# Find the row with the closest "price" to the missing "rentZestimate"
closest_price = df.loc[~missing_index, 'price'].sub(missing_price).abs().idxmin()

# Fill the missing "rentZestimate" with the value from the closest price
df.loc[missing_index, 'rentZestimate'] = df.loc[closest_price, 'rentZestimate']

# %%
df[missing_index]
# Out:
#     zipcode       streetAddress       homeType  yearBuilt  lotAreaValue  \
# 28    90019  1436 S Ridgeley Dr  SINGLE_FAMILY       1995           NaN
#
#     livingAreaValue  garageParkingCapacity  bedrooms  bathrooms  stories  \
# 28        77.481102                    NaN         2        1.0      NaN
#
#              flooring      heating cooling  fireplaceFeatures  \
# 28  [Laminate, Slate]  [Wall, Gas]  [Wall]                  0
#
#     taxAssessedValue  zestimate  rentZestimate sold-history  price  \
# 28          525587.5        NaN         6111.0           []   2975
#
#     Unnamed: 30
# 28          NaN

# %%
df.loc[closest_price]
# Out:
# zipcode                                       90402
# streetAddress            109 Chautauqua Blvd APT 14
# homeType                                      CONDO
# yearBuilt                                      1924
# lotAreaValue                                    NaN
# livingAreaValue                                 NaN
# garageParkingCapacity                           NaN
# bedrooms                                          1
# bathrooms                                       1.0
# stories                                         NaN
# flooring                             [Tile, Carpet]
# heating                                      [Wall]
# cooling                                      [None]
# fireplaceFeatures                                 0
# taxAssessedValue                           525587.5
# zestimate                                       NaN
# rentZestimate                                6111.0
# sold-history                                     []
# price                                          2990
# Unnamed: 30                                     NaN
# Name: 15, dtype: object

# %%
df["lotAreaValue"].isna().sum()
# Out:
# 77

# %%
df["livingAreaValue"].isna().sum()
# Out:
# 21

# %%
((df["livingAreaValue"].isna())&(df["lotAreaValue"].isna())).sum()
# Out:
# 3

# %%
#drop rows  livingAreaValue or lotAreaValue is null
df.dropna(subset=["livingAreaValue", "lotAreaValue"], inplace=True)
